# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append("..")
import src.generate_resource_inventory as gri
import src.generate_social_network as gsn
import src.generate_sharing_group as gsg
import src.resource_sharing_model as rsm
import src.evaluation_metrics as em

# %%
def p2p_resource_sharing(isolation_day=5):
    # Social network construction
    distance_matrix = np.load("../temp/laurelhurst_distance_matrix.npy")
    strong_tie_matrix, weak_tie_matrix, stranger_matrix = gsn.get_social_network(distance_matrix, 
                                                                                 prop_fri = 0.41296054954979877,
                                                                                 degree_para=[17.40, -0.58],
                                                                                 dist_decay_alpha=-1.35)
    # willingness-to-share matrix
    share_group_proportion = np.loadtxt("../temp/laurelhurst_share_group_proportion")
    share_group = gsg.get_share_group(distance_matrix.shape[0], share_group_proportion)
    wts_matrix = gsg.get_willingness_to_share(strong_tie_matrix, weak_tie_matrix, stranger_matrix, share_group)
    # resource inventory
    resource_probability = np.loadtxt("../temp/laurelhurst_resource_inventory_prob_mass")
    inventory = gri.get_resource_inventory(distance_matrix.shape[0], resource_probability)
    # solve the model
    model = rsm.ResourceSharingModel(wts_matrix, inventory, isolation_day)
    model.solve()
    return model

# %%
# plot the resource distribution among the community as a Lorenz curve
def plot_lorenz_curve(resource_inventory, savefig=False, path="../figs/lorenz_curve.png"):
    num_households = len(resource_inventory)
    total_resource = sum(resource_inventory)
    resource_inventory = sorted(resource_inventory)

    # calculate the cumulative resource inventory
    cum_resource_inventory = [0]
    for i in range(num_households):
        cum_resource_inventory.append(cum_resource_inventory[i] + resource_inventory[i]/total_resource)

    # plot the 45 degree line
    fig, ax = plt.subplots(1, 1, figsize=(4, 4))
    plt.plot(np.linspace(0, 1, num_households+1), np.linspace(0, 1, num_households+1), linewidth=2, color='b', label="Equal distribution line")

    # plot the Lorenz curve
    plt.plot(np.linspace(0, 1, num_households+1), cum_resource_inventory, linewidth=2, color='r', label="Actual distribution line")

    # fill the area between the Lorenz curve and the 45 degree line
    # plt.fill_between(np.linspace(0, 1, num_households+1), cum_resource_inventory, np.linspace(0, 1, num_households+1), color='grey', alpha=0.3)

    plt.xlabel("Cumulative proportion of households")
    plt.ylabel("Cumulative proportion of resources")
    plt.legend()

    if savefig:
        plt.savefig(path, dpi=300)

# %%
model = p2p_resource_sharing(isolation_day=3)
# The survival curve of the first week
t = np.arange(0, 10, 0.1)
plt.plot(t, em.get_survival_curve(model.resource, t), color='b', linewidth=3, label='survival curve')
plt.xlabel('Time/day')
plt.ylabel('Number of survival households')
plt.legend()
plt.xlim(0, 10)
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x0fe6dde7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 2690 rows and 3473203 columns
# Presolve time: 0.75s
# Presolved: 1056 rows, 34926 columns, 69744 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.536e+04
#  Factor NZ  : 2.793e+04 (roughly 7 MB of memory)
#  Factor Ops : 1.849e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.79 seconds (1.87 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       93    8.4000000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      978 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1199    8.4000000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 1199 iterations and 1.07 seconds (2.14 work units)
# Optimal objective  8.400000000e+02
# (0.0, 10.0)

# %%
resource_inventory = np.loadtxt("../temp/resource_inventory")
plot_lorenz_curve(resource_inventory)
plot_lorenz_curve(model.resource)

# %%
model = p2p_resource_sharing(isolation_day=4)
# The survival curve of the first week
t = np.arange(0, 10, 0.1)
plt.plot(t, em.get_survival_curve(model.resource, t), color='b', linewidth=3, label='survival curve')
plt.xlabel('Time/day')
plt.ylabel('Number of survival households')
plt.legend()
plt.xlim(0, 10)
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xdf816973
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 2586 rows and 3435208 columns
# Presolve time: 0.79s
# Presolved: 1160 rows, 72921 columns, 145750 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.872e+04
#  Factor NZ  : 7.144e+04 (roughly 17 MB of memory)
#  Factor Ops : 1.068e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.85 seconds (2.19 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      287    1.3890000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2739 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 10
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3189    1.3890000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3189 iterations and 1.24 seconds (2.99 work units)
# Optimal objective  1.389000000e+03
# (0.0, 10.0)

# %%
resource_inventory = np.loadtxt("../temp/resource_inventory")
plot_lorenz_curve(resource_inventory)
plot_lorenz_curve(model.resource)

# %%
model = p2p_resource_sharing(isolation_day=5)
# The survival curve of the first week
t = np.arange(0, 10, 0.1)
plt.plot(t, em.get_survival_curve(model.resource, t), color='b', linewidth=3, label='survival curve')
plt.xlabel('Time/day')
plt.ylabel('Number of survival households')
plt.legend()
plt.xlim(0, 10)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-04-25
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x63d67a17
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2365 rows and 3360499 columns
# Presolve time: 0.79s
# Presolved: 1381 rows, 147630 columns, 295177 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.072e+05
#  Factor NZ  : 2.087e+05 (roughly 45 MB of memory)
#  Factor Ops : 7.103e+07 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.64653946e+05  2.07240769e+03  2.31e+02 1.61e+01  1.09e+01     1s
#    1   1.88992645e+05  6.32805227e+03  4.27e+01 2.13e-14  2.03e+00     1s
#
# Barrier performed 1 iterations in 0.95 seconds (2.13 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      395 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5213    2.1600000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 5213 iterations and 1.26 seconds (2.45 work units)
# Optimal objective  2.160000000e+03
# (0.0, 10.0)

# %%
resource_inventory = np.loadtxt("../temp/laurelhurst_resource_inventory")
plot_lorenz_curve(resource_inventory, savefig=True, path="../figs/lorenz_curve_before.png")
plot_lorenz_curve(model.resource, savefig=True, path="../figs/lorenz_curve_after.png")
# Out:
# /Users/lzy95/anaconda3/lib/python3.10/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
import geopandas as gpd
import pandas as pd
import contextily as cx

households_df = pd.read_csv("../address keys/laurelhurst_address.csv")

node_list = households_df['ID'].tolist()
node_pos = households_df[['longitude', 'latitude']].values

geometry = gpd.points_from_xy(node_pos[:,0], node_pos[:,1])
gdf = gpd.GeoDataFrame(households_df, geometry=geometry)
gdf.crs = {'init': 'epsg:4326'}

fig, ax = plt.subplots(figsize=(10, 10))

# set the node color to be proportional to the resource inventory
resource_inventory = np.loadtxt("../temp/laurelhurst_resource_inventory")
cmap = plt.cm.get_cmap('copper')  # Choose a colormap
node_color = resource_inventory / max(resource_inventory)
node_color_mapped = cmap(node_color)

# Plot the GeoDataFrame
gdf.plot(ax=ax, markersize=10, color=node_color_mapped, alpha=1)

# add base map
cx.add_basemap(ax, crs=gdf.crs.to_string(), source=cx.providers.Stamen.TonerLite)

# Add color bar
sm = plt.cm.ScalarMappable(cmap=cmap)
sm.set_array(resource_inventory)
cbar = plt.colorbar(sm, ax=ax, shrink=0.7)
cbar.set_label('Resource Inventory (days)')

plt.axis('off')
plt.show()

# save the figure
fig.savefig("../figs/laurelhurst_transp_resource_inventory.png", dpi=300, bbox_inches='tight')
# Out:
# /Users/lzy95/anaconda3/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/0w/g946thld1vq1mh93x_4vjy8c0000gq/T/ipykernel_2639/3981929252.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('copper')  # Choose a colormap
# Warning 1: +init=epsg:XXXX syntax is deprecated. It might return a CRS with a non-EPSG compliant axis order.

# %%
households_df = pd.read_csv("../address keys/laurelhurst_address.csv")

node_list = households_df['ID'].tolist()
node_pos = households_df[['longitude', 'latitude']].values

geometry = gpd.points_from_xy(node_pos[:,0], node_pos[:,1])
gdf = gpd.GeoDataFrame(households_df, geometry=geometry)
gdf.crs = {'init': 'epsg:4326'}

fig, ax = plt.subplots(figsize=(10, 10))

# set the node color to be proportional to the resource inventory
resource_inventory = model.resource
cmap = plt.cm.get_cmap('copper')  # Choose a colormap
node_color = resource_inventory / max(resource_inventory)
node_color_mapped = cmap(node_color)

# Plot the GeoDataFrame
gdf.plot(ax=ax, markersize=10, color=node_color_mapped, alpha=1)

# add base map
cx.add_basemap(ax, crs=gdf.crs.to_string(), source=cx.providers.Stamen.TonerLite)

# Add color bar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=7))
cbar = plt.colorbar(sm, ax=ax, shrink=0.7)
cbar.set_label('Resource redistribution (days)')

plt.axis('off')
plt.show()

# save the figure
fig.savefig("../figs/laurelhurst_transp_resource_redistribution.png", dpi=300, bbox_inches='tight')
# Out:
# /Users/lzy95/anaconda3/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/0w/g946thld1vq1mh93x_4vjy8c0000gq/T/ipykernel_2639/694340816.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('copper')  # Choose a colormap

# %%
model = p2p_resource_sharing(isolation_day=6)
# The survival curve of the first week
t = np.arange(0, 10, 0.1)
plt.plot(t, em.get_survival_curve(model.resource, t), color='b', linewidth=3, label='survival curve')
plt.xlabel('Time/day')
plt.ylabel('Number of survival households')
plt.legend()
plt.xlim(0, 10)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-04-25
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x4163800d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2262 rows and 3289860 columns
# Presolve time: 0.85s
# Presolved: 1484 rows, 218269 columns, 436470 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.182e+05
#  Factor NZ  : 4.040e+05 (roughly 100 MB of memory)
#  Factor Ops : 2.165e+08 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.26916164e+05  2.39444599e+03  9.02e+02 2.01e+00  2.10e+00     1s
#    1   1.01270278e+05  3.97178421e+03  2.01e+02 5.85e-01  4.69e-01     1s
#    2   1.66428164e+04  3.84323546e+03  2.73e+01 1.05e-01  6.61e-02     1s
#    3   4.95880594e+03  3.36953935e+03  4.97e+00 2.59e-02  1.33e-02     1s
#    4   3.38908072e+03  3.20714306e+03  1.75e+00 1.28e-02  5.30e-03     1s
#
# Barrier performed 4 iterations in 1.04 seconds (2.56 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    17522    2.8560000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 17522 iterations and 1.34 seconds (2.85 work units)
# Optimal objective  2.856000000e+03
# (0.0, 10.0)

# %%
resource_inventory = np.loadtxt("../temp/laurelhurst_resource_inventory")
plot_lorenz_curve(resource_inventory)
plot_lorenz_curve(model.resource)
# Out:
# /Users/lzy95/anaconda3/lib/python3.10/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
model = p2p_resource_sharing(isolation_day=7)
# The survival curve of the first week
t = np.arange(0, 10, 0.1)
plt.plot(t, em.get_survival_curve(model.resource, t), color='b', linewidth=3, label='survival curve')
plt.xlabel('Time/day')
plt.ylabel('Number of survival households')
plt.legend()
plt.xlim(0, 10)
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x279a4689
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 7e+00]
# Presolve removed 3746 rows and 3508129 columns
# Presolve time: 0.41s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -0.0000000e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 0 iterations and 0.67 seconds (1.13 work units)
# Optimal objective -0.000000000e+00
# (0.0, 10.0)

# %%
resource_inventory = np.loadtxt("../temp/resource_inventory")
plot_lorenz_curve(resource_inventory)
plot_lorenz_curve(model.resource)
