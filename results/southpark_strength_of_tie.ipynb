# %%
import numpy as np
import scipy.sparse as sp
import pandas as pd

import sys
sys.path.append('..')
import src

# %%
PARAMS = {
    'community': 'southpark',
    'experiment_name': 'strength_of_tie',
    # resource types should be the same as the column names in the resource_preference_pmf and resource_inventory_pmf
    'resource_types': ['water', 'food', 'meds', 'transp', 'comm',
                       'faid', 'warm', 'sani', 'power', 'shelter'], 
    'tau': 5, # isolation days
    'num_scenarios': 100,
    'n': 0.82661451, # degree distribution parameter
    'p': 0.06686762, # degree distribution parameter
    'social_tie': {
        'types': ['strong', 'weak'],
        'pmf':  [0.298, 0.702]
    },
    'distance_decay_alpha': -1.43, # distance decay parameter
    'distances_mat': np.load('../temp/southpark_distance_matrix.npy'), # distance matrix
    'sharing_preference_pmf': pd.read_csv('../temp/southpark_share_pref_PMF.csv'), # sharing preference matrix
    'sharing_priority': [3, 2, 1], # sharing priorities to [strong tie, weak tie, stranger]
    'resource_inventory_pmf': pd.read_csv('../temp/southpark_resource_distr_PMF.csv') # resource inventory distribution
}

# %%
def p2p_single_resource_sharing(resource:str, 
                                tau:float, # isolation days
                                n:float, # negative binomial distribution parameter
                                p:float, # negative binomial distribution parameter
                                distance_decay_alpha:float, # distance decay parameter
                                distance_mat:np.matrix, # distance matrix
                                sharing_preference_PMF:pd.Series, 
                                resource_inventory_PMF:pd.Series,
                                social_tie_pmf:list,
                                social_tie_types:list = ['strong', 'weak'],
                                sharing_priority:list = [3, 2, 1],
                                seed:int=0):
    """Step 1: Community-based social network construction"""
    # create a community
    community = src.Community()
    num_nodes = distance_mat.shape[0]
    community.add_nodes_from(range(num_nodes))

    # generate social ties
    np.random.seed(seed)
    degree_list = np.random.negative_binomial(n, p, size=num_nodes)
    community.generate_social_ties(degrees=degree_list, 
                                   distance_matrix=distance_mat, 
                                   distance_decay_alpha=distance_decay_alpha, 
                                   seed=seed+1)
    community.split_social_ties(types=social_tie_types, 
                                pmf=social_tie_pmf, 
                                seed=seed+2)

    """Step 2: Community-based resource-sharing network construction"""
    # generate sharing preferences
    community.generate_sharing_preference(recipient=[0, 1, 2, 3], # [nobody, strong tie only, strong and weak ties only, everybody]
                                          pmf=sharing_preference_PMF, 
                                          name=resource+'_share_preference',
                                          seed=seed+3)

    """Step 3: Community-based resource inventory"""
    community.generate_resource_inventory(support=np.arange(0, len(resource_inventory_PMF)), 
                                          pmf=resource_inventory_PMF, 
                                          name=resource, 
                                          seed=seed+4)

    # create sharing network
    share_network = community.get_share_network(sharing_preference=resource+'_share_preference', 
                                                priority=sharing_priority)

    """Step 4: Community-based P2P resource-sharing model"""
    priority_matrix = community.get_share_priority_matrix(sharing_preference=resource+'_share_preference', 
                                                          priority=sharing_priority)
    resource_inventory = [community.nodes[n][resource] for n in community.nodes]
    model = src.ResourceSharingModel(wts_matrix=priority_matrix, 
                                     inventory=resource_inventory, 
                                     isolation_days=tau)
    model.solve()

    return community, share_network, model

# %%
# main script for running the status quo model
for tie_prop in [[0.0, 1.0],
                 [0.1, 0.9],
                 [0.2, 0.8],
                 [0.3, 0.7],
                 [0.4, 0.6],
                 [0.5, 0.5],
                 [0.6, 0.4],
                 [0.7, 0.3],
                 [0.8, 0.2],
                 [0.9, 0.1],
                 [1.0, 0.0]]:

    for sce in range(PARAMS['num_scenarios']):
        
        # directory name for saving the results
        dir = PARAMS['community'] + '/' + PARAMS['experiment_name'] + '/tau_' + str(PARAMS['tau']) # directory name
        # Create a dataframe to store the results
        inventory_df = pd.DataFrame(columns=PARAMS['resource_types'])
        resource_df = pd.DataFrame(columns=PARAMS['resource_types'])
        
        # run the model for each resource type
        for rsc in PARAMS['resource_types']:
            community, share_network, model = p2p_single_resource_sharing(resource=rsc,
                                                                        tau=PARAMS['tau'],
                                                                        n=PARAMS['n'],
                                                                        p=PARAMS['p'],
                                                                        social_tie_types = PARAMS['social_tie']['types'],
                                                                        social_tie_pmf = tie_prop,
                                                                        distance_decay_alpha = PARAMS['distance_decay_alpha'],
                                                                        distance_mat = PARAMS['distances_mat'],
                                                                        sharing_preference_PMF = PARAMS['sharing_preference_pmf'][rsc],
                                                                        sharing_priority = PARAMS['sharing_priority'],
                                                                        resource_inventory_PMF = PARAMS['resource_inventory_pmf'][rsc],
                                                                        seed=sce)
            inventory_df[rsc] = model.inventory.flatten()
            resource_df[rsc] = model.resource.flatten()

        # save the resource inventory vector in csv file
        inventory_df.to_csv(dir + '/q_vec_tie_{}_sce_{}.csv'.format(tie_prop, sce), index=False)
        # save the final resource vector in csv file
        resource_df.to_csv(dir + '/h_vec_tie_{}_sce_{}.csv'.format(tie_prop, sce), index=False)
# Out:
# e:\Github repos\Community-based_P2P_resource_sharing\results\..\src\community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\Github repos\Community-based_P2P_resource_sharing\results\southpark_strength_of_tie.ipynb Cell 4 in <cell line: 2>()
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=21'>22</a> # run the model for each resource type
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=22'>23</a> for rsc in PARAMS['resource_types']:
# ---> <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=23'>24</a>     community, share_network, model = p2p_single_resource_sharing(resource=rsc,
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=24'>25</a>                                                                 tau=PARAMS['tau'],
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=25'>26</a>                                                                 n=PARAMS['n'],
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=26'>27</a>                                                                 p=PARAMS['p'],
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=27'>28</a>                                                                 social_tie_types = PARAMS['social_tie']['types'],
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=28'>29</a>                                                                 social_tie_pmf = tie_prop,
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=29'>30</a>                                                                 distance_decay_alpha = PARAMS['distance_decay_alpha'],
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=30'>31</a>                                                                 distance_mat = PARAMS['distances_mat'],
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=31'>32</a>                                                                 sharing_preference_PMF = PARAMS['sharing_preference_pmf'][rsc],
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=32'>33</a>                                                                 sharing_priority = PARAMS['sharing_priority'],
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=33'>34</a>                                                                 resource_inventory_PMF = PARAMS['resource_inventory_pmf'][rsc],
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=34'>35</a>                                                                 seed=sce)
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=35'>36</a>     inventory_df[rsc] = model.inventory.flatten()
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=36'>37</a>     resource_df[rsc] = model.resource.flatten()
#
# e:\Github repos\Community-based_P2P_resource_sharing\results\southpark_strength_of_tie.ipynb Cell 4 in p2p_single_resource_sharing(resource, tau, n, p, distance_decay_alpha, distance_mat, sharing_preference_PMF, resource_inventory_PMF, social_tie_pmf, social_tie_types, sharing_priority, seed)
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=37'>38</a> community.generate_resource_inventory(support=np.arange(0, len(resource_inventory_PMF)),
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=38'>39</a>                                       pmf=resource_inventory_PMF,
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=39'>40</a>                                       name=resource,
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=40'>41</a>                                       seed=seed+4)
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=42'>43</a> # create sharing network
# ---> <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=43'>44</a> share_network = community.get_share_network(sharing_preference=resource+'_share_preference',
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=44'>45</a>                                             priority=sharing_priority)
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=46'>47</a> """Step 4: Community-based P2P resource-sharing model"""
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=47'>48</a> priority_matrix = community.get_share_priority_matrix(sharing_preference=resource+'_share_preference',
#      <a href='vscode-notebook-cell:/e%3A/Github%20repos/Community-based_P2P_resource_sharing/results/southpark_strength_of_tie.ipynb#W3sZmlsZQ%3D%3D?line=48'>49</a>                                                       priority=sharing_priority)
#
# File e:\Github repos\Community-based_P2P_resource_sharing\results\..\src\community.py:284, in Community.get_share_network(self, sharing_preference, priority)
#     274 def get_share_network(self, sharing_preference, priority=[3, 2, 1]):
#     275     """
#     276     Method:
#     277         Construct the share network based on the sharing preference and social ties.
#    (...)
#     282         G: the share network
#     283     """
# --> 284     priority_matrix = self.get_share_priority_matrix(sharing_preference, priority)
#     285     G = nx.from_numpy_matrix(priority_matrix, create_using=nx.DiGraph)
#     286     # set the node attributes
#
# File e:\Github repos\Community-based_P2P_resource_sharing\results\..\src\community.py:254, in Community.get_share_priority_matrix(self, sharing_preference, priority)
#     251 weak_tie_matrix = self.get_social_tie_matrix(type='weak')
#     253 n = strong_tie_matrix.shape[0]
# --> 254 stranger_matrix = np.ones(shape=(n, n)) - self.get_social_tie_matrix()
#     256 # create willingness to share matrix
#     257 priority_matrix = np.zeros((n, n))
#
# File e:\Github repos\Community-based_P2P_resource_sharing\results\..\src\community.py:230, in Community.get_social_tie_matrix(self, type)
#     226 """
#     227 This function returns the social tie matrix.
#     228 """
#     229 if type is None:
# --> 230     return nx.adjacency_matrix(self).todense()
#     231 else:
#     232     # return the adjacency matrix of edges with the given type
#     233     matrix = np.zeros((len(self.nodes()), len(self.nodes())), dtype=int)
#
# File e:\software\Anaconda\lib\site-packages\networkx\linalg\graphmatrix.py:173, in adjacency_matrix(G, nodelist, dtype, weight)
#     167 warnings.warn(
#     168     "adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.",
#     169     FutureWarning,
#     170     stacklevel=2,
#     171 )
#     172 # TODO: Change to `to_scipy_sparse_array` for networkx 3.0
# --> 173 return nx.to_scipy_sparse_matrix(G, nodelist=nodelist, dtype=dtype, weight=weight)
#
# File e:\software\Anaconda\lib\site-packages\networkx\convert_matrix.py:1019, in to_scipy_sparse_matrix(G, nodelist, dtype, weight, format)
#    1009 import scipy.sparse
#    1011 warnings.warn(
#    1012     (
#    1013         "\n\nThe scipy.sparse array containers will be used instead of matrices\n"
#    (...)
#    1017     stacklevel=2,
#    1018 )
# -> 1019 A = to_scipy_sparse_array(
#    1020     G, nodelist=nodelist, dtype=dtype, weight=weight, format=format
#    1021 )
#    1022 return sp.sparse.csr_matrix(A).asformat(format)
#
# File e:\software\Anaconda\lib\site-packages\networkx\convert_matrix.py:921, in to_scipy_sparse_array(G, nodelist, dtype, weight, format)
#     919         r += diag_index
#     920         c += diag_index
# --> 921     A = sp.sparse.coo_array((d, (r, c)), shape=(nlen, nlen), dtype=dtype)
#     922 try:
#     923     return A.asformat(format)
#
# AttributeError: module 'scipy.sparse' has no attribute 'coo_array'
