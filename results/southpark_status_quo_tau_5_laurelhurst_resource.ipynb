# %%
import numpy as np
import scipy.sparse as sp
import pandas as pd

import sys
sys.path.append('..')
import src

# %%
PARAMS = {
    'community': 'southpark',
    'experiment_name': 'status_quo_laurelhurst_resource',
    # resource types should be the same as the column names in the resource_preference_pmf and resource_inventory_pmf
    'resource_types': ['water', 'food', 'meds', 'transp', 'comm',
                       'faid', 'warm', 'sani', 'power', 'shelter'], 
    'tau': 5, # isolation days
    'num_scenarios': 100,
    'n': 0.82661451, # degree distribution parameter
    'p': 0.06686762, # degree distribution parameter
    'social_tie': {
        'types': ['strong', 'weak'],
        'pmf':  [0.298, 0.702]
    },
    'distance_decay_alpha': -1.43, # distance decay parameter
    'distances_mat': np.load('../temp/southpark_distance_matrix.npy'), # distance matrix
    'sharing_preference_pmf': pd.read_csv('../temp/southpark_share_pref_PMF.csv'), # sharing preference matrix
    'sharing_priority': [3, 2, 1], # sharing priorities to [strong tie, weak tie, stranger]
    'resource_inventory_pmf': pd.read_csv('../temp/laurelhurst_resource_distr_PMF.csv') # resource inventory distribution
}

# %%
def p2p_single_resource_sharing(resource:str, 
                                tau:float, # isolation days
                                n:float, # negative binomial distribution parameter
                                p:float, # negative binomial distribution parameter
                                distance_decay_alpha:float, # distance decay parameter
                                distance_mat:np.matrix, # distance matrix
                                sharing_preference_PMF:pd.Series, 
                                resource_inventory_PMF:pd.Series,
                                social_tie_pmf:list,
                                social_tie_types:list = ['strong', 'weak'],
                                sharing_priority:list = [3, 2, 1],
                                seed:int=0):
    """Step 1: Community-based social network construction"""
    # create a community
    community = src.Community()
    num_nodes = distance_mat.shape[0]
    community.add_nodes_from(range(num_nodes))

    # generate social ties
    np.random.seed(seed)
    degree_list = np.random.negative_binomial(n, 
                                              p, 
                                              size=num_nodes)
    community.generate_social_ties(degrees=degree_list, 
                                   distance_matrix=distance_mat, 
                                   distance_decay_alpha=distance_decay_alpha, 
                                   seed=seed+1)
    community.split_social_ties(types=social_tie_types, 
                                pmf=social_tie_pmf, 
                                seed=seed+2)

    """Step 2: Community-based resource-sharing network construction"""
    # generate sharing preferences
    community.generate_sharing_preference(recipient=[0, 1, 2, 3], # [nobody, strong tie only, strong and weak ties only, everybody]
                                          pmf=sharing_preference_PMF, 
                                          name=resource+'_share_preference',
                                          seed=seed+3)

    """Step 3: Community-based resource inventory"""
    community.generate_resource_inventory(support=np.arange(0, len(resource_inventory_PMF)), 
                                          pmf=resource_inventory_PMF, 
                                          name=resource, 
                                          seed=seed+4)

    # create sharing network
    share_network = community.get_share_network(sharing_preference=resource+'_share_preference', 
                                                priority=sharing_priority)

    """Step 4: Community-based P2P resource-sharing model"""
    priority_matrix = community.get_share_priority_matrix(sharing_preference=resource+'_share_preference', 
                                                          priority=sharing_priority)
    resource_inventory = [community.nodes[n][resource] for n in community.nodes]
    model = src.ResourceSharingModel(wts_matrix=priority_matrix, 
                                     inventory=resource_inventory, 
                                     isolation_days=tau)
    model.solve()

    return community, share_network, model

# %%
# main script for running the status quo model
for sce in range(PARAMS['num_scenarios']):
    
    # directory name for saving the results
    dir = PARAMS['community'] + '/' + PARAMS['experiment_name'] + '/tau_' + str(PARAMS['tau']) # directory name
    # Create a dataframe to store the results
    inventory_df = pd.DataFrame(columns=PARAMS['resource_types'])
    resource_df = pd.DataFrame(columns=PARAMS['resource_types'])
    
    # run the model for each resource type
    for rsc in PARAMS['resource_types']:
        community, share_network, model = p2p_single_resource_sharing(resource=rsc,
                                                                    tau=PARAMS['tau'],
                                                                    n=PARAMS['n'],
                                                                    p=PARAMS['p'],
                                                                    social_tie_types = PARAMS['social_tie']['types'],
                                                                    social_tie_pmf = PARAMS['social_tie']['pmf'],
                                                                    distance_decay_alpha = PARAMS['distance_decay_alpha'],
                                                                    distance_mat = PARAMS['distances_mat'],
                                                                    sharing_preference_PMF = PARAMS['sharing_preference_pmf'][rsc],
                                                                    sharing_priority = PARAMS['sharing_priority'],
                                                                    resource_inventory_PMF = PARAMS['resource_inventory_pmf'][rsc],
                                                                    seed=sce)
        inventory_df[rsc] = model.inventory.flatten()
        resource_df[rsc] = model.resource.flatten()

        # save the sharing priority matrix in a sparse matrix
        # sp.save_npz(dir + '/wij_mat_sce_{}_{}.npz'.format(sce, rsc), sp.csr_matrix(model.wts_matrix))
        # save the sharing plan in a sparse matrix
        # sp.save_npz(dir + '/xij_mat_sce_{}_{}.npz'.format(sce, rsc), sp.csr_matrix(model.share_plan))

    # save the resource inventory vector in csv file
    inventory_df.to_csv(dir + '/q_vec_sce_{}.csv'.format(sce), index=False)
    # save the final resource vector in csv file
    resource_df.to_csv(dir + '/h_vec_sce_{}.csv'.format(sce), index=False)
# Out:
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x1e43c5cb
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1700 rows and 1789243 columns
# Presolve time: 0.67s
# Presolved: 1058 rows, 112398 columns, 224754 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.137e+04
#  Factor NZ  : 1.085e+05 (roughly 26 MB of memory)
#  Factor Ops : 1.791e+07 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.80 seconds (1.04 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      496    1.6100000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1217 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1926    1.6100000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 1926 iterations and 1.08 seconds (1.21 work units)
# Optimal objective  1.610000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xa0ed9f0b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1824 rows and 1797762 columns
# Presolve time: 0.69s
# Presolved: 934 rows, 103879 columns, 207693 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.536e+04
#  Factor NZ  : 1.060e+05 (roughly 23 MB of memory)
#  Factor Ops : 2.036e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.96116153e+05  4.59622629e+03  2.31e+02 8.72e+01  7.29e+01     1s
#    1   1.48660379e+05  3.57012152e+04  1.16e+02 1.14e-13  3.72e+01     1s
#    2   1.26321692e+04  2.41370695e+04  8.97e+00 1.14e-13  3.03e+00     1s
#
# Barrier performed 2 iterations in 0.83 seconds (1.04 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      826    1.9460000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     4309 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.2360000e+03      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5510    1.9460000e+03   0.000000e+00   2.236000e+03      1s
# Extra simplex iterations after uncrush: 2
#     5533    1.9460000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 5533 iterations and 1.23 seconds (1.44 work units)
# Optimal objective  1.946000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x21581ed8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2286 rows and 1880098 columns
# Presolve time: 0.73s
# Presolved: 472 rows, 21543 columns, 43035 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.843e+03
#  Factor NZ  : 7.393e+03 (roughly 2 MB of memory)
#  Factor Ops : 4.478e+05 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.74 seconds (0.98 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       97    5.3100000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     5927 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6103    5.3100000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6103 iterations and 1.02 seconds (1.13 work units)
# Optimal objective  5.310000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x52570929
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1937 rows and 1815197 columns
# Presolve time: 0.83s
# Presolved: 821 rows, 86444 columns, 172805 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.714e+04
#  Factor NZ  : 6.996e+04 (roughly 16 MB of memory)
#  Factor Ops : 1.539e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.76501194e+05  1.38949641e+03  1.40e+02 1.61e+01  1.11e+01     1s
#    1   7.36186612e+04  2.91089237e+03  2.58e+01 2.49e-14  2.06e+00     1s
#
# Barrier performed 1 iterations in 0.93 seconds (1.23 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2246    1.4890000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     4155 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.5400000e+02      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6575    1.4890000e+03   0.000000e+00   3.540000e+02      1s
# Extra simplex iterations after uncrush: 119
#     6697    1.4890000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 6697 iterations and 1.42 seconds (1.83 work units)
# Optimal objective  1.489000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x35345d02
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1613 rows and 1699818 columns
# Presolve time: 0.79s
# Presolved: 1145 rows, 201823 columns, 403602 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.181e+05
#  Factor NZ  : 2.086e+05 (roughly 50 MB of memory)
#  Factor Ops : 6.013e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.51169948e+06  2.11702223e+03  3.63e+02 1.61e+01  1.41e+01     1s
#
# Barrier performed 0 iterations in 1.07 seconds (1.23 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5426    2.4810000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     5166 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    10991    2.4810000e+03   0.000000e+00   1.000000e+00      1s
# Extra simplex iterations after uncrush: 5
#    10997    2.4810000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 10997 iterations and 1.53 seconds (1.73 work units)
# Optimal objective  2.481000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x19ae2cce
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1717 rows and 1713233 columns
# Presolve time: 0.83s
# Presolved: 1041 rows, 188408 columns, 376762 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.031e+05
#  Factor NZ  : 1.823e+05 (roughly 40 MB of memory)
#  Factor Ops : 6.382e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.10805363e+05  1.97369279e+03  9.97e+01 3.15e+01  1.06e+01     1s
#    1   6.70350263e+04  5.50399129e+03  1.29e+01 3.43e+00  1.39e+00     1s
#    2   1.17181302e+04  5.08291193e+03  1.99e+00 1.17e+00  2.25e-01     1s
#    3   5.20055567e+03  4.61686850e+03  7.10e-01 7.14e-01  8.58e-02     1s
#    4   4.83162249e+03  4.28727126e+03  6.35e-01 1.95e-01  7.39e-02     1s
#    5   2.00188746e+03  3.75793609e+03  6.81e-02 2.91e-01  1.61e-02     1s
#
# Barrier performed 5 iterations in 1.15 seconds (1.25 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    10638 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.2120000e+03      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    17873    2.3990000e+03   0.000000e+00   1.212000e+03      1s
#    17935    2.3990000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 17935 iterations and 1.48 seconds (1.45 work units)
# Optimal objective  2.399000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x06788730
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 2007 rows and 1880787 columns
# Presolve time: 0.85s
# Presolved: 751 rows, 20854 columns, 41684 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.762e+03
#  Factor NZ  : 3.071e+03 (roughly 1 MB of memory)
#  Factor Ops : 9.233e+04 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.86 seconds (0.99 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       36    2.2100000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     6331 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6404    2.2100000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6404 iterations and 1.13 seconds (1.15 work units)
# Optimal objective  2.210000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xcb25bdfe
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1669 rows and 1790310 columns
# Presolve time: 0.65s
# Presolved: 1089 rows, 111331 columns, 222606 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.291e+04
#  Factor NZ  : 1.138e+05 (roughly 27 MB of memory)
#  Factor Ops : 1.890e+07 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.80 seconds (1.06 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      719    2.0480000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2943 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3931    2.0480000e+03   0.000000e+00   1.000000e+00      1s
# Extra simplex iterations after uncrush: 3
#     3935    2.0480000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3935 iterations and 1.16 seconds (1.49 work units)
# Optimal objective  2.048000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xc2635ac4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1640 rows and 1831725 columns
# Presolve time: 0.62s
# Presolved: 1118 rows, 69916 columns, 139791 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.757e+04
#  Factor NZ  : 6.474e+04 (roughly 16 MB of memory)
#  Factor Ops : 6.203e+06 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.70 seconds (0.99 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      422    1.4170000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1179 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 7
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1811    1.4170000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 1811 iterations and 1.04 seconds (1.43 work units)
# Optimal objective  1.417000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x7396e0b3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1832 rows and 1827615 columns
# Presolve time: 0.70s
# Presolved: 926 rows, 74026 columns, 147957 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.135e+04
#  Factor NZ  : 7.811e+04 (roughly 18 MB of memory)
#  Factor Ops : 1.114e+07 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.80 seconds (1.17 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      875    2.5400000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     4455 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5637    2.5400000e+03   0.000000e+00   4.000000e+00      1s
# Extra simplex iterations after uncrush: 4
#     5643    2.5400000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 5643 iterations and 1.21 seconds (1.60 work units)
# Optimal objective  2.540000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x1a48f135
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1695 rows and 1787361 columns
# Presolve time: 0.67s
# Presolved: 1063 rows, 114280 columns, 228508 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.716e+04
#  Factor NZ  : 1.151e+05 (roughly 30 MB of memory)
#  Factor Ops : 1.941e+07 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.81 seconds (1.04 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1732 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2223    1.6290000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 2223 iterations and 1.07 seconds (1.21 work units)
# Optimal objective  1.629000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x4a8d015d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1821 rows and 1790012 columns
# Presolve time: 0.75s
# Presolved: 937 rows, 111629 columns, 223180 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.856e+04
#  Factor NZ  : 1.273e+05 (roughly 30 MB of memory)
#  Factor Ops : 2.778e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.83126105e+05  1.89729910e+03  2.43e+02 1.60e+01  1.21e+01     1s
#    1   1.71136854e+05  4.66930336e+03  6.00e+01 2.84e-14  3.05e+00     1s
#    2   8.67945124e+03  3.81405441e+03  2.55e+00 1.42e-14  1.44e-01     1s
#
# Barrier performed 2 iterations in 0.93 seconds (1.06 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1743 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1320000e+03      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6121    2.0700000e+03   0.000000e+00   1.132000e+03      1s
# Extra simplex iterations after uncrush: 43
#     6175    2.0700000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 6175 iterations and 1.33 seconds (1.47 work units)
# Optimal objective  2.070000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x3aeacc1a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2286 rows and 1881130 columns
# Presolve time: 0.73s
# Presolved: 472 rows, 20511 columns, 40975 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.423e+03
#  Factor NZ  : 8.142e+03 (roughly 2 MB of memory)
#  Factor Ops : 4.981e+05 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.74 seconds (0.88 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       71    5.5700000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     5208 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 26
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5374    5.5700000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 5374 iterations and 1.15 seconds (1.30 work units)
# Optimal objective  5.570000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x88d91317
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1957 rows and 1825503 columns
# Presolve time: 0.84s
# Presolved: 801 rows, 76138 columns, 152173 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.932e+04
#  Factor NZ  : 7.036e+04 (roughly 17 MB of memory)
#  Factor Ops : 1.409e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.26922103e+05  1.56014393e+03  1.63e+02 1.60e+01  1.20e+01     1s
#    1   7.39637255e+04  3.33044669e+03  2.67e+01 2.13e-14  1.99e+00     1s
#
# Barrier performed 1 iterations in 0.94 seconds (1.28 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1779    1.4900000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1894 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3832    1.4900000e+03   0.000000e+00   2.000000e+00      1s
#     3833    1.4900000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3833 iterations and 1.22 seconds (1.45 work units)
# Optimal objective  1.490000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x4f15ecce
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1621 rows and 1693684 columns
# Presolve time: 0.81s
# Presolved: 1137 rows, 207957 columns, 415865 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.319e+05
#  Factor NZ  : 2.361e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.457e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.00540476e+06  5.16885413e+03  4.51e+02 8.78e+01  1.02e+02     1s
#
# Barrier performed 0 iterations in 1.11 seconds (1.21 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     4712 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6288    2.5290000e+03   0.000000e+00   7.000000e+00      1s
#     6291    2.5290000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 6291 iterations and 1.46 seconds (1.43 work units)
# Optimal objective  2.529000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xd7660ed9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1698 rows and 1705111 columns
# Presolve time: 0.83s
# Presolved: 1060 rows, 196530 columns, 393008 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.204e+05
#  Factor NZ  : 2.134e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.121e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.59153567e+05  1.67571873e+03  6.63e+01 1.61e+01  3.30e+00     1s
#    1   7.46744733e+04  3.38768064e+03  1.32e+01 2.43e+00  6.63e-01     1s
#    2   4.36430759e+03  3.33368191e+03  4.02e-01 1.13e+00  2.55e-02     1s
#    3   3.04054072e+03  2.98266769e+03  1.72e-01 9.03e-01  1.14e-02     1s
#    4   2.34974184e+03  2.84057544e+03  3.21e-02 6.20e-01  4.33e-03     1s
#    5   2.35864319e+03  2.67841697e+03  1.33e-02 3.95e-01  2.29e-03     1s
#
# Barrier performed 5 iterations in 1.21 seconds (1.30 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     8760 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.7600000e+02      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    19386    2.4800000e+03   0.000000e+00   8.760000e+02      1s
#    19397    2.4800000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 19397 iterations and 1.55 seconds (1.49 work units)
# Optimal objective  2.480000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x6ec77ef0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 2007 rows and 1887032 columns
# Presolve time: 0.72s
# Presolved: 751 rows, 14609 columns, 29185 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.290e+03
#  Factor NZ  : 2.765e+03 (roughly 1 MB of memory)
#  Factor Ops : 7.284e+04 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.73 seconds (0.86 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       28    2.7200000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     5405 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 4
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5484    2.7200000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 5484 iterations and 1.08 seconds (1.23 work units)
# Optimal objective  2.720000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xc3ce8727
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1649 rows and 1775434 columns
# Presolve time: 0.66s
# Presolved: 1109 rows, 126207 columns, 252355 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 8.013e+04
#  Factor NZ  : 1.382e+05 (roughly 34 MB of memory)
#  Factor Ops : 2.565e+07 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.82 seconds (1.07 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1895 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2536    2.1200000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 2536 iterations and 1.08 seconds (1.25 work units)
# Optimal objective  2.120000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x57edaaba
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1629 rows and 1824680 columns
# Presolve time: 0.60s
# Presolved: 1129 rows, 76961 columns, 153873 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.248e+04
#  Factor NZ  : 7.266e+04 (roughly 18 MB of memory)
#  Factor Ops : 7.589e+06 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.70 seconds (0.87 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      439    1.4210000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1080 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 5
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1722    1.4210000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 1722 iterations and 1.05 seconds (1.28 work units)
# Optimal objective  1.421000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x5d4ee2da
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1809 rows and 1815378 columns
# Presolve time: 0.65s
# Presolved: 949 rows, 86263 columns, 172420 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.379e+04
#  Factor NZ  : 1.018e+05 (roughly 23 MB of memory)
#  Factor Ops : 1.798e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.71956635e+05  4.33759982e+03  3.43e+02 1.59e+01  4.61e+01     1s
#
# Barrier performed 0 iterations in 0.79 seconds (1.03 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1034    2.7960000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     3985 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5364    2.7960000e+03   0.000000e+00   3.000000e+00      1s
#     5366    2.7960000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 5366 iterations and 1.09 seconds (1.22 work units)
# Optimal objective  2.796000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x9419724d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1710 rows and 1794784 columns
# Presolve time: 0.70s
# Presolved: 1048 rows, 106857 columns, 213666 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.982e+04
#  Factor NZ  : 1.023e+05 (roughly 25 MB of memory)
#  Factor Ops : 1.591e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.24222749e+06  1.93902179e+03  6.53e+02 1.61e+01  2.45e+01     1s
#
# Barrier performed 0 iterations in 0.85 seconds (1.17 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      370 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1145    1.5490000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 1145 iterations and 1.15 seconds (1.35 work units)
# Optimal objective  1.549000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x40654668
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1849 rows and 1797429 columns
# Presolve time: 0.67s
# Presolved: 909 rows, 104212 columns, 208362 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.023e+04
#  Factor NZ  : 1.087e+05 (roughly 25 MB of memory)
#  Factor Ops : 1.983e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.26721441e+05  4.31892188e+03  3.36e+02 7.03e+01  7.24e+01     1s
#    1   1.95910414e+05  2.81227424e+04  1.54e+02 9.95e-14  3.37e+01     1s
#    2   2.16131990e+04  1.99827369e+04  1.62e+01 8.53e-14  3.64e+00     1s
#
# Barrier performed 2 iterations in 0.82 seconds (1.04 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      983    1.8920000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     3952 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.3000000e+01      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5220    1.8920000e+03   0.000000e+00   1.300000e+01      1s
# Extra simplex iterations after uncrush: 9
#     5231    1.8920000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 5231 iterations and 1.28 seconds (1.45 work units)
# Optimal objective  1.892000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x21dc9354
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2298 rows and 1883046 columns
# Presolve time: 0.73s
# Presolved: 460 rows, 18595 columns, 37139 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.328e+03
#  Factor NZ  : 6.049e+03 (roughly 1 MB of memory)
#  Factor Ops : 3.110e+05 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.74 seconds (0.96 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       77    5.2000000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     6066 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6209    5.2000000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6209 iterations and 0.98 seconds (1.11 work units)
# Optimal objective  5.200000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x02aaf0e1
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1990 rows and 1827791 columns
# Presolve time: 0.82s
# Presolved: 768 rows, 73850 columns, 147609 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.369e+04
#  Factor NZ  : 6.384e+04 (roughly 14 MB of memory)
#  Factor Ops : 1.309e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.38977393e+05  1.40382458e+03  1.30e+02 1.61e+01  1.12e+01     1s
#    1   6.16785996e+04  3.00749204e+03  2.22e+01 2.13e-14  1.93e+00     1s
#    2   4.03574388e+03  2.46569904e+03  1.05e+00 1.07e-14  1.06e-01     1s
#
# Barrier performed 2 iterations in 0.91 seconds (1.20 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3065    1.4810000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2683 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7200000e+02      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5920    1.4810000e+03   0.000000e+00   1.720000e+02      1s
# Extra simplex iterations after uncrush: 18
#     5942    1.4810000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 5942 iterations and 1.32 seconds (1.59 work units)
# Optimal objective  1.481000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x29c5cc3d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1623 rows and 1694162 columns
# Presolve time: 0.88s
# Presolved: 1135 rows, 207479 columns, 414907 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.268e+05
#  Factor NZ  : 2.177e+05 (roughly 50 MB of memory)
#  Factor Ops : 6.203e+07 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 1.14 seconds (1.54 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
# ...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4537    2.0760000e+03   0.000000e+00   1.060000e+02      1s
# Extra simplex iterations after uncrush: 1
#     4553    2.0760000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 4553 iterations and 1.35 seconds (1.46 work units)
# Optimal objective  2.076000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x62f9dbdc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2264 rows and 1876447 columns
# Presolve time: 0.78s
# Presolved: 494 rows, 25194 columns, 50326 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.229e+03
#  Factor NZ  : 9.490e+03 (roughly 2 MB of memory)
#  Factor Ops : 6.573e+05 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.81 seconds (1.03 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       95    7.0500000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     6936 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 10
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7132    7.0500000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 7132 iterations and 1.20 seconds (1.41 work units)
# Optimal objective  7.050000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xcc61080c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1917 rows and 1811542 columns
# Presolve time: 0.77s
# Presolved: 841 rows, 90099 columns, 180105 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.904e+04
#  Factor NZ  : 9.298e+04 (roughly 20 MB of memory)
#  Factor Ops : 2.394e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.47648797e+05  1.61743711e+03  1.40e+02 1.61e+01  1.04e+01     1s
#    1   8.59598666e+04  3.50831739e+03  2.57e+01 1.78e-14  1.92e+00     1s
#    2   4.65170746e+03  3.16203179e+03  1.03e+00 1.42e-14  9.58e-02     1s
#
# Barrier performed 2 iterations in 0.95 seconds (1.01 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3573    1.6330000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2234 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0000000e+01      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6008    1.6330000e+03   0.000000e+00   1.000000e+01      1s
# Extra simplex iterations after uncrush: 22
#     6034    1.6330000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 6034 iterations and 1.36 seconds (1.40 work units)
# Optimal objective  1.633000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xeaeab9ac
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1614 rows and 1698650 columns
# Presolve time: 0.83s
# Presolved: 1144 rows, 202991 columns, 405932 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.337e+05
#  Factor NZ  : 2.447e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.779e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.50016272e+06  2.13062317e+03  3.44e+02 1.60e+01  1.24e+01     1s
#    1   3.94379581e+05  5.29844800e+03  8.89e+01 2.13e-14  3.26e+00     1s
#    2   1.56407796e+04  4.38596936e+03  3.16e+00 1.42e-14  1.25e-01     1s
#
# Barrier performed 2 iterations in 1.27 seconds (1.27 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     3722 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 6.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6427    2.5510000e+03   0.000000e+00   6.000000e+00      1s
#     6430    2.5510000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 6430 iterations and 1.65 seconds (1.48 work units)
# Optimal objective  2.551000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xd51ea1b4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1696 rows and 1706352 columns
# Presolve time: 0.87s
# Presolved: 1062 rows, 195289 columns, 390522 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.219e+05
#  Factor NZ  : 2.238e+05 (roughly 50 MB of memory)
#  Factor Ops : 9.046e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.33744264e+05  1.74280371e+03  1.36e+02 1.61e+01  6.68e+00     1s
#    1   1.69141064e+05  4.35174264e+03  3.02e+01 2.13e-14  1.51e+00     1s
#    2   7.04822137e+03  3.73623258e+03  9.55e-01 1.07e-14  5.46e-02     1s
#    3   3.20645981e+03  3.40540823e+03  2.36e-01 1.07e-14  1.70e-02     1s
#    4   2.58835613e+03  3.08360678e+03  8.96e-02 1.07e-14  7.65e-03     1s
#
# Barrier performed 4 iterations in 1.34 seconds (1.28 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     8915 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.6370000e+03      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    20501    2.5570000e+03   0.000000e+00   1.637000e+03      1s
# Extra simplex iterations after uncrush: 3
#    20523    2.5570000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 20523 iterations and 1.83 seconds (1.72 work units)
# Optimal objective  2.557000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xa9bdaac1
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 1996 rows and 1878031 columns
# Presolve time: 0.88s
# Presolved: 762 rows, 23610 columns, 47185 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.187e+03
#  Factor NZ  : 5.383e+03 (roughly 1 MB of memory)
#  Factor Ops : 2.207e+05 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.90 seconds (1.12 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       59    3.3200000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     4536 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4652    3.3200000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 4652 iterations and 1.22 seconds (1.27 work units)
# Optimal objective  3.320000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xe6a741fc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1661 rows and 1773336 columns
# Presolve time: 0.71s
# Presolved: 1097 rows, 128305 columns, 256558 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 7.767e+04
#  Factor NZ  : 1.370e+05 (roughly 30 MB of memory)
#  Factor Ops : 2.622e+07 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.91 seconds (1.07 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2262 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 9.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3512    2.0610000e+03   0.000000e+00   9.000000e+00      1s
#     3514    2.0610000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3514 iterations and 1.25 seconds (1.27 work units)
# Optimal objective  2.061000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x92239735
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1625 rows and 1816903 columns
# Presolve time: 0.74s
# Presolved: 1133 rows, 84738 columns, 169431 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.800e+04
#  Factor NZ  : 8.360e+04 (roughly 20 MB of memory)
#  Factor Ops : 1.012e+07 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.91 seconds (1.02 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      462    1.4580000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1081 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1772    1.4580000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 1772 iterations and 1.24 seconds (1.20 work units)
# Optimal objective  1.458000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xde116b67
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1805 rows and 1813950 columns
# Presolve time: 0.71s
# Presolved: 953 rows, 87691 columns, 175281 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.307e+04
#  Factor NZ  : 1.016e+05 (roughly 22 MB of memory)
#  Factor Ops : 1.714e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.29114398e+05  3.42232393e+03  3.83e+02 1.59e+01  3.78e+01     1s
#
# Barrier performed 0 iterations in 0.88 seconds (1.00 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      875    2.6510000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     4640 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 6.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5855    2.6510000e+03   0.000000e+00   6.000000e+00      1s
# Extra simplex iterations after uncrush: 9
#     5871    2.6510000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 5871 iterations and 1.36 seconds (1.45 work units)
# Optimal objective  2.651000000e+03
