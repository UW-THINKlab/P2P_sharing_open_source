# %%
import numpy as np
import scipy.sparse as sp
import pandas as pd
import networkx as nx

import sys
sys.path.append('..')
import src

# %% [markdown]
# Here we consider an idea social network that the whole community is fully connected, i.e., each household is connected to every other household with strong tie.

# %%
PARAMS = {
    'community': 'southpark',
    'experiment_name': 'ideal_social_net',
    # resource types should be the same as the column names in the resource_preference_pmf and resource_inventory_pmf
    'resource_types': ['water', 'food', 'meds', 'transp', 'comm',
                       'faid', 'warm', 'sani', 'power', 'shelter'], 
    'tau': 5, # isolation days
    'num_scenarios': 100,
    'n': 0.82661451, # degree distribution parameter
    'p': 0.06686762, # degree distribution parameter
    'social_tie': {
        'types': ['strong', 'weak'],
        'pmf':  [1, 0]
    },
    'distance_decay_alpha': -1.43, # distance decay parameter
    'distances_mat': np.load('../temp/southpark_distance_matrix.npy'), # distance matrix
    'sharing_preference_pmf': pd.read_csv('../temp/southpark_share_pref_PMF.csv'), # sharing preference matrix
    'sharing_priority': [3, 2, 1], # sharing priorities to [strong tie, weak tie, stranger]
    'resource_inventory_pmf': pd.read_csv('../temp/southpark_resource_distr_PMF.csv') # resource inventory distribution
}

# %%
def p2p_single_resource_sharing(resource:str, 
                                tau:float, # isolation days
                                n:float, # negative binomial distribution parameter
                                p:float, # negative binomial distribution parameter
                                distance_decay_alpha:float, # distance decay parameter
                                distance_mat:np.matrix, # distance matrix
                                sharing_preference_PMF:pd.Series, 
                                resource_inventory_PMF:pd.Series,
                                social_tie_pmf:list,
                                social_tie_types:list = ['strong', 'weak'],
                                sharing_priority:list = [3, 2, 1],
                                seed:int=0):
    """Step 1: Community-based social network construction"""
    # create a community
    community = src.Community()
    num_nodes = distance_mat.shape[0]
    community.add_nodes_from(range(num_nodes))

    # generate a fully connected social network
    community.add_edges_from(nx.complete_graph(num_nodes).edges)
    community.split_social_ties(types=social_tie_types, 
                                pmf=social_tie_pmf, 
                                seed=seed+2)

    """Step 2: Community-based resource-sharing network construction"""
    # generate sharing preferences
    community.generate_sharing_preference(recipient=[0, 1, 2, 3], # [nobody, strong tie only, strong and weak ties only, everybody]
                                          pmf=sharing_preference_PMF, 
                                          name=resource+'_share_preference',
                                          seed=seed+3)

    """Step 3: Community-based resource inventory"""
    community.generate_resource_inventory(support=np.arange(0, len(resource_inventory_PMF)), 
                                          pmf=resource_inventory_PMF, 
                                          name=resource, 
                                          seed=seed+4)

    # create sharing network
    share_network = community.get_share_network(sharing_preference=resource+'_share_preference', 
                                                priority=sharing_priority)

    """Step 4: Community-based P2P resource-sharing model"""
    priority_matrix = community.get_share_priority_matrix(sharing_preference=resource+'_share_preference', 
                                                          priority=sharing_priority)
    resource_inventory = [community.nodes[n][resource] for n in community.nodes]
    model = src.ResourceSharingModel(wts_matrix=priority_matrix, 
                                     inventory=resource_inventory, 
                                     isolation_days=tau)
    model.solve()

    return community, share_network, model

# %%
# main script for running the status quo model
for sce in range(PARAMS['num_scenarios']):
    
    # directory name for saving the results
    dir = PARAMS['community'] + '/' + PARAMS['experiment_name'] + '/tau_' + str(PARAMS['tau']) # directory name
    # Create a dataframe to store the results
    inventory_df = pd.DataFrame(columns=PARAMS['resource_types'])
    resource_df = pd.DataFrame(columns=PARAMS['resource_types'])
    
    # run the model for each resource type
    for rsc in PARAMS['resource_types']:
        community, share_network, model = p2p_single_resource_sharing(resource=rsc,
                                                                    tau=PARAMS['tau'],
                                                                    n=PARAMS['n'],
                                                                    p=PARAMS['p'],
                                                                    social_tie_types = PARAMS['social_tie']['types'],
                                                                    social_tie_pmf = PARAMS['social_tie']['pmf'],
                                                                    distance_decay_alpha = PARAMS['distance_decay_alpha'],
                                                                    distance_mat = PARAMS['distances_mat'],
                                                                    sharing_preference_PMF = PARAMS['sharing_preference_pmf'][rsc],
                                                                    sharing_priority = PARAMS['sharing_priority'],
                                                                    resource_inventory_PMF = PARAMS['resource_inventory_pmf'][rsc],
                                                                    seed=sce)
        inventory_df[rsc] = model.inventory.flatten()
        resource_df[rsc] = model.resource.flatten()

    # save the resource inventory vector in csv file
    inventory_df.to_csv(dir + '/q_vec_sce_{}.csv'.format(sce), index=False)
    # save the final resource vector in csv file
    resource_df.to_csv(dir + '/h_vec_sce_{}.csv'.format(sce), index=False)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-31
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xda292d4b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1518 rows and 1552585 columns
# Presolve time: 0.72s
# Presolved: 1240 rows, 349056 columns, 698112 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2740000e+03   8.670876e-01   0.000000e+00      1s
#        9    2.2740000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   158552 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   158990    2.2740000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 158990 iterations and 1.21 seconds (1.12 work units)
# Optimal objective  2.274000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x28499700
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1557 rows and 1584097 columns
# Presolve time: 0.88s
# Presolved: 1201 rows, 317544 columns, 635088 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8290000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      383 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   262514 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   262900    2.8290000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 262900 iterations and 1.48 seconds (1.10 work units)
# Optimal objective  2.829000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x0adae5e7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1690 rows and 1768585 columns
# Presolve time: 0.71s
# Presolved: 1068 rows, 133056 columns, 266112 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.3900000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      127 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   125119 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   125249    9.3900000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 125249 iterations and 1.11 seconds (0.88 work units)
# Optimal objective  9.390000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x50e882fd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1500 rows and 1683241 columns
# Presolve time: 0.81s
# Presolved: 1258 rows, 218400 columns, 436800 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6320000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      166 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   203798 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   203967    1.6320000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 203967 iterations and 1.33 seconds (0.98 work units)
# Optimal objective  1.632000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xd00e7876
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1466 rows and 1488949 columns
# Presolve time: 0.78s
# Presolved: 1292 rows, 412692 columns, 825384 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.0650000e+03   2.222481e-01   0.000000e+00      1s
#        3    4.0650000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   336682 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   337392    4.0650000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 337392 iterations and 1.61 seconds (1.50 work units)
# Optimal objective  4.065000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x03b365ff
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1499 rows and 1525111 columns
# Presolve time: 0.88s
# Presolved: 1259 rows, 376530 columns, 753060 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.3470000e+03   4.765625e-01   0.000000e+00      1s
#        4    4.3470000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   339659 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   339741    4.3470000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 339741 iterations and 1.90 seconds (1.49 work units)
# Optimal objective  4.347000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x37358f9b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1420 rows and 1816484 columns
# Presolve time: 0.74s
# Presolved: 1338 rows, 85157 columns, 170314 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.5500000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       64 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    83948 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    84015    5.5500000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 84015 iterations and 1.06 seconds (0.86 work units)
# Optimal objective  5.550000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x1c687cb8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1484 rows and 1499968 columns
# Presolve time: 0.81s
# Presolved: 1274 rows, 401673 columns, 803346 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9840000e+03   4.283333e-01   0.000000e+00      1s
#        1    3.9840000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   209312 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   210004    3.9840000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 210004 iterations and 1.42 seconds (1.24 work units)
# Optimal objective  3.984000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x21505c55
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1497 rows and 1585621 columns
# Presolve time: 0.66s
# Presolved: 1261 rows, 316020 columns, 632040 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8060000e+03   8.556623e-01   0.000000e+00      1s
#        9    1.8060000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    76667 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    77019    1.8060000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 77019 iterations and 1.05 seconds (1.04 work units)
# Optimal objective  1.806000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xf7ff3748
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1462 rows and 1498121 columns
# Presolve time: 0.85s
# Presolved: 1296 rows, 403520 columns, 807040 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.7024710e+03   6.183126e-02   0.000000e+00      1s
#        6    4.5270000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   350776 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   351537    4.5270000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 351537 iterations and 1.52 seconds (1.29 work units)
# Optimal objective  4.527000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x5cb98acd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1534 rows and 1568713 columns
# Presolve time: 0.69s
# Presolved: 1224 rows, 332928 columns, 665856 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1540000e+03   8.719788e-01   0.000000e+00      1s
#        8    2.1540000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    68246 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    68661    2.1540000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 68661 iterations and 1.11 seconds (1.05 work units)
# Optimal objective  2.154000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xb009a175
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1550 rows and 1582621 columns
# Presolve time: 0.83s
# Presolved: 1208 rows, 319020 columns, 638040 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.7060000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      376 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   262456 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   262835    2.7060000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 262835 iterations and 1.41 seconds (1.09 work units)
# Optimal objective  2.706000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x67597b90
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1710 rows and 1779946 columns
# Presolve time: 0.79s
# Presolved: 1048 rows, 121695 columns, 243390 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.8100000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      107 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   116216 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   116326    9.8100000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 116326 iterations and 1.25 seconds (0.87 work units)
# Optimal objective  9.810000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xbeefcd27
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1499 rows and 1694161 columns
# Presolve time: 0.83s
# Presolved: 1259 rows, 207480 columns, 414960 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5600000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      149 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   191444 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   191596    1.5600000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 191596 iterations and 1.31 seconds (0.97 work units)
# Optimal objective  1.560000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x48f62e92
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1483 rows and 1502207 columns
# Presolve time: 1.01s
# Presolved: 1275 rows, 399434 columns, 798868 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.0740000e+03   2.160128e-01   0.000000e+00      1s
#        3    4.0740000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   320443 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   321160    4.0740000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 321160 iterations and 1.85 seconds (1.33 work units)
# Optimal objective  4.074000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x60238182
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1495 rows and 1528289 columns
# Presolve time: 0.98s
# Presolved: 1263 rows, 373352 columns, 746704 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.4340000e+03   3.948020e-01   0.000000e+00      1s
#        5    4.2540000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   334667 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   335046    4.2540000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 335046 iterations and 1.80 seconds (1.38 work units)
# Optimal objective  4.254000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x76f32974
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1419 rows and 1812811 columns
# Presolve time: 0.79s
# Presolved: 1339 rows, 88830 columns, 177660 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.3000000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       60 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    88050 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    88113    6.3000000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 88113 iterations and 1.15 seconds (0.86 work units)
# Optimal objective  6.300000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x644d3c2a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1502 rows and 1513186 columns
# Presolve time: 0.82s
# Presolved: 1256 rows, 388455 columns, 776910 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9810000e+03   3.933594e-01   0.000000e+00      1s
#        1    3.9810000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   200621 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   201318    3.9810000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 201318 iterations and 1.43 seconds (1.24 work units)
# Optimal objective  3.981000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x99315621
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1493 rows and 1588905 columns
# Presolve time: 0.68s
# Presolved: 1265 rows, 312736 columns, 625472 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7010000e+03   6.365879e-01   0.000000e+00      1s
#        6    1.7010000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   111650 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   111991    1.7010000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 111991 iterations and 1.13 seconds (1.05 work units)
# Optimal objective  1.701000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x360d919b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1456 rows and 1497721 columns
# Presolve time: 0.92s
# Presolved: 1302 rows, 403920 columns, 807840 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.8181390e+03   6.040115e-02   0.000000e+00      1s
#        5    4.6350000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   385522 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   385540    4.6350000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 385540 iterations and 1.63 seconds (1.32 work units)
# Optimal objective  4.635000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x1c47cc17
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1526 rows and 1560994 columns
# Presolve time: 0.71s
# Presolved: 1232 rows, 340647 columns, 681294 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2140000e+03   8.516237e-01   0.000000e+00      1s
#       10    2.2140000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   150212 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   150638    2.2140000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 150638 iterations and 1.24 seconds (1.11 work units)
# Optimal objective  2.214000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x72bb82ee
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1566 rows and 1581021 columns
# Presolve time: 0.93s
# Presolved: 1192 rows, 320620 columns, 641240 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.7960000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      399 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   263209 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   263611    2.7960000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 263611 iterations and 1.65 seconds (1.10 work units)
# Optimal objective  2.796000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x45354f3e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1730 rows and 1781086 columns
# Presolve time: 0.77s
# Presolved: 1028 rows, 120555 columns, 241110 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.3900000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      117 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   115677 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   115797    9.3900000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 115797 iterations and 1.14 seconds (0.87 work units)
# Optimal objective  9.390000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xb628b882
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1491 rows and 1679671 columns
# Presolve time: 0.77s
# Presolved: 1267 rows, 221970 columns, 443940 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5690000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      168 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   203448 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   203619    1.5690000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 203619 iterations and 1.27 seconds (0.99 work units)
# Optimal objective  1.569000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xf36cad07
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1476 rows and 1492785 columns
# Presolve time: 0.81s
# Presolved: 1282 rows, 408856 columns, 817712 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9330000e+03   1.873095e-01   0.000000e+00      1s
#        2    3.9330000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   288684 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   289366    3.9330000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 289366 iterations and 1.60 seconds (1.42 work units)
# Optimal objective  3.933000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xd179ccfd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1496 rows and 1516705 columns
# Presolve time: 0.78s
# Presolved: 1262 rows, 384936 columns, 769872 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.2120000e+03   3.604911e-01   0.000000e+00      1s
#        4    4.2120000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   349371 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   349453    4.2120000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 349453 iterations and 1.54 seconds (1.37 work units)
# Optimal objective  4.212000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x7bb8cf01
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1428 rows and 1815825 columns
# Presolve time: 0.82s
# Presolved: 1330 rows, 85816 columns, 171632 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.7600000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       63 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    85063 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    85129    5.7600000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 85129 iterations and 1.16 seconds (0.86 work units)
# Optimal objective  5.760000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x482ec504
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1496 rows and 1505001 columns
# Presolve time: 0.80s
# Presolved: 1262 rows, 396640 columns, 793280 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.8400000e+03   3.630319e-01   0.000000e+00      1s
#        1    3.8400000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   205100 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   205764    3.8400000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 205764 iterations and 1.40 seconds (1.28 work units)
# Optimal objective  3.840000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x3228c7e7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1496 rows and 1589916 columns
# Presolve time: 0.68s
# Presolved: 1262 rows, 311725 columns, 623450 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7850000e+03   5.766616e-01   0.000000e+00      1s
#        6    1.7850000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   111833 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   112174    1.7850000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 112174 iterations and 1.16 seconds (1.05 work units)
# Optimal objective  1.785000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x98e0ef11
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1477 rows and 1502957 columns
# Presolve time: 0.80s
# Presolved: 1281 rows, 398684 columns, 797368 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.8527920e+03   7.235463e-02   0.000000e+00      1s
#        5    4.3800000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   382036 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   382064    4.3800000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 382064 iterations and 1.59 seconds (1.27 work units)
# Optimal objective  4.380000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xf1a9219e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1513 rows and 1558025 columns
# Presolve time: 0.78s
# Presolved: 1245 rows, 343616 columns, 687232 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1990000e+03   7.915771e-01   0.000000e+00      1s
#       10    2.1990000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   157966 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   158386    2.1990000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 158386 iterations and 1.27 seconds (1.12 work units)
# Optimal objective  2.199000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x29e9fa03
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1551 rows and 1569649 columns
# Presolve time: 0.79s
# Presolved: 1207 rows, 331992 columns, 663984 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9760000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      406 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   274310 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   274719    2.9760000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 274719 iterations and 1.36 seconds (1.14 work units)
# Optimal objective  2.976000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xbd27b98e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1716 rows and 1773841 columns
# Presolve time: 0.74s
# Presolved: 1042 rows, 127800 columns, 255600 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0410000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      116 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   120532 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   120651    1.0410000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 120651 iterations and 1.13 seconds (0.87 work units)
# Optimal objective  1.041000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xb5a30356
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1500 rows and 1676569 columns
# Presolve time: 0.76s
# Presolved: 1258 rows, 225072 columns, 450144 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7190000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      170 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   205586 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   205759    1.7190000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 205759 iterations and 1.24 seconds (0.99 work units)
# Optimal objective  1.719000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x8c0a5017
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
# ...
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   109303 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   109657    1.8300000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 109657 iterations and 1.21 seconds (1.08 work units)
# Optimal objective  1.830000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x514ee5e3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1463 rows and 1494375 columns
# Presolve time: 0.83s
# Presolved: 1295 rows, 407266 columns, 814532 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.7713600e+03   6.771875e-02   0.000000e+00      1s
#        5    4.4310000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   389187 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   389209    4.4310000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 389209 iterations and 1.61 seconds (1.33 work units)
# Optimal objective  4.431000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xc8457af7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1515 rows and 1550161 columns
# Presolve time: 0.81s
# Presolved: 1243 rows, 351480 columns, 702960 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3100000e+03   8.411212e-01   0.000000e+00      1s
#        9    2.3100000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   110070 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   110512    2.3100000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 110512 iterations and 1.34 seconds (1.10 work units)
# Optimal objective  2.310000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x787f86ec
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1561 rows and 1581659 columns
# Presolve time: 0.77s
# Presolved: 1197 rows, 319982 columns, 639964 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9160000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      387 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   270800 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   271190    2.9160000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 271190 iterations and 1.39 seconds (1.11 work units)
# Optimal objective  2.916000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x3c4c8a07
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1694 rows and 1764541 columns
# Presolve time: 0.78s
# Presolved: 1064 rows, 137100 columns, 274200 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1670000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      121 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   128971 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   129095    1.1670000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 129095 iterations and 1.26 seconds (0.88 work units)
# Optimal objective  1.167000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x7a420778
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1504 rows and 1684912 columns
# Presolve time: 0.80s
# Presolved: 1254 rows, 216729 columns, 433458 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7790000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      149 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   199697 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   199849    1.7790000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 199849 iterations and 1.29 seconds (0.98 work units)
# Optimal objective  1.779000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xbdec0974
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1460 rows and 1485769 columns
# Presolve time: 0.88s
# Presolved: 1298 rows, 415872 columns, 831744 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.1070000e+03   2.208180e-01   0.000000e+00      1s
#        3    4.1070000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   335631 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   336349    4.1070000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 336349 iterations and 1.57 seconds (1.33 work units)
# Optimal objective  4.107000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x82359a17
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1497 rows and 1523571 columns
# Presolve time: 0.82s
# Presolved: 1261 rows, 378070 columns, 756140 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.3530000e+03   3.689413e-01   0.000000e+00      1s
#        4    4.3530000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   343079 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   343161    4.3530000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 343161 iterations and 1.73 seconds (1.48 work units)
# Optimal objective  4.353000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x1067383b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1418 rows and 1790302 columns
# Presolve time: 0.82s
# Presolved: 1340 rows, 111339 columns, 222678 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.7100000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       83 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   110354 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   110440    7.7100000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 110440 iterations and 1.17 seconds (0.89 work units)
# Optimal objective  7.710000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x06855d6b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1471 rows and 1492241 columns
# Presolve time: 0.82s
# Presolved: 1287 rows, 409400 columns, 818800 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.0740000e+03   1.282371e-02   0.000000e+00      1s
#        1    4.0740000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   238785 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   239496    4.0740000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 239496 iterations and 1.46 seconds (1.28 work units)
# Optimal objective  4.074000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xd9c3f870
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1485 rows and 1578019 columns
# Presolve time: 0.73s
# Presolved: 1273 rows, 323622 columns, 647244 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8120000e+03   5.474139e-01   0.000000e+00      1s
#        6    1.8120000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   111910 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   112264    1.8120000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 112264 iterations and 1.23 seconds (1.07 work units)
# Optimal objective  1.812000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x2426b6c8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1455 rows and 1491951 columns
# Presolve time: 0.84s
# Presolved: 1303 rows, 409690 columns, 819380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.8148270e+03   6.424298e-02   0.000000e+00      1s
#        5    4.5360000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   393175 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   393192    4.5360000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 393192 iterations and 1.69 seconds (1.31 work units)
# Optimal objective  4.536000000e+03
