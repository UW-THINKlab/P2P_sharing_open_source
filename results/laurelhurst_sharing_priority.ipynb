# %%
import numpy as np
import scipy.sparse as sp
import pandas as pd

import sys
sys.path.append('..')
import src

# %%
PARAMS = {
    'community': 'laurelhurst',
    'experiment_name': 'sharing_priority',
    # resource types should be the same as the column names in the resource_preference_pmf and resource_inventory_pmf
    'resource_types': ['water', 'food', 'meds', 'transp', 'comm',
                       'faid', 'warm', 'sani', 'power', 'shelter'], 
    'tau': 5, # isolation days
    'num_scenarios': 100,
    'n': 0.78773808, # degree distribution parameter
    'p': 0.02559534, # degree distribution parameter
    'social_tie': {
        'types': ['strong', 'weak'],
        'pmf':  [0.41296, 0.58704]
    },
    'distance_decay_alpha': -1.35, # distance decay parameter
    'distances_mat': np.load('../temp/laurelhurst_distance_matrix.npy'), # distance matrix
    'sharing_preference_pmf': pd.read_csv('../temp/laurelhurst_share_pref_PMF.csv'), # sharing preference matrix
    'sharing_priority': [1, 1, 1], # sharing priorities to [strong tie, weak tie, stranger]
    'resource_inventory_pmf': pd.read_csv('../temp/laurelhurst_resource_distr_PMF.csv') # resource inventory distribution
}

# %%
def p2p_single_resource_sharing(resource:str, 
                                tau:float, # isolation days
                                n:float, # negative binomial distribution parameter
                                p:float, # negative binomial distribution parameter
                                distance_decay_alpha:float, # distance decay parameter
                                distance_mat:np.matrix, # distance matrix
                                sharing_preference_PMF:pd.Series, 
                                resource_inventory_PMF:pd.Series,
                                social_tie_pmf:list,
                                social_tie_types:list = ['strong', 'weak'],
                                sharing_priority:list = [3, 2, 1],
                                seed:int=0):
    """Step 1: Community-based social network construction"""
    # create a community
    community = src.Community()
    num_nodes = distance_mat.shape[0]
    community.add_nodes_from(range(num_nodes))

    # generate social ties
    np.random.seed(seed)
    degree_list = np.random.negative_binomial(n, p, size=num_nodes)
    community.generate_social_ties(degrees=degree_list, 
                                   distance_matrix=distance_mat, 
                                   distance_decay_alpha=distance_decay_alpha, 
                                   seed=seed+1)
    community.split_social_ties(types=social_tie_types, 
                                pmf=social_tie_pmf, 
                                seed=seed+2)

    """Step 2: Community-based resource-sharing network construction"""
    # generate sharing preferences
    community.generate_sharing_preference(recipient=[0, 1, 2, 3], # [nobody, strong tie only, strong and weak ties only, everybody]
                                          pmf=sharing_preference_PMF, 
                                          name=resource+'_share_preference',
                                          seed=seed+3)

    """Step 3: Community-based resource inventory"""
    community.generate_resource_inventory(support=np.arange(0, len(resource_inventory_PMF)), 
                                          pmf=resource_inventory_PMF, 
                                          name=resource, 
                                          seed=seed+4)

    # create sharing network
    share_network = community.get_share_network(sharing_preference=resource+'_share_preference', 
                                                priority=sharing_priority)

    """Step 4: Community-based P2P resource-sharing model"""
    priority_matrix = community.get_share_priority_matrix(sharing_preference=resource+'_share_preference', 
                                                          priority=sharing_priority)
    resource_inventory = [community.nodes[n][resource] for n in community.nodes]
    model = src.ResourceSharingModel(wts_matrix=priority_matrix, 
                                     inventory=resource_inventory, 
                                     isolation_days=tau)
    model.solve()

    return community, share_network, model

# %%
# main script for running the status quo model
for sce in range(PARAMS['num_scenarios']):
    
    # directory name for saving the results
    dir = PARAMS['community'] + '/' + PARAMS['experiment_name'] + '/tau_' + str(PARAMS['tau']) # directory name
    # Create a dataframe to store the results
    inventory_df = pd.DataFrame(columns=PARAMS['resource_types'])
    resource_df = pd.DataFrame(columns=PARAMS['resource_types'])
    
    # run the model for each resource type
    for rsc in PARAMS['resource_types']:
        community, share_network, model = p2p_single_resource_sharing(resource=rsc,
                                                                    tau=PARAMS['tau'],
                                                                    n=PARAMS['n'],
                                                                    p=PARAMS['p'],
                                                                    social_tie_types = PARAMS['social_tie']['types'],
                                                                    social_tie_pmf = PARAMS['social_tie']['pmf'],
                                                                    distance_decay_alpha = PARAMS['distance_decay_alpha'],
                                                                    distance_mat = PARAMS['distances_mat'],
                                                                    sharing_preference_PMF = PARAMS['sharing_preference_pmf'][rsc],
                                                                    sharing_priority = PARAMS['sharing_priority'],
                                                                    resource_inventory_PMF = PARAMS['resource_inventory_pmf'][rsc],
                                                                    seed=sce)
        inventory_df[rsc] = model.inventory.flatten()
        resource_df[rsc] = model.resource.flatten()

    # save the resource inventory vector in csv file
    inventory_df.to_csv(dir + '/q_vec_priority_[1, 1, 1]_sce_{}.csv'.format(sce), index=False)
    # save the final resource vector in csv file
    resource_df.to_csv(dir + '/h_vec_priority_[1, 1, 1]_sce_{}.csv'.format(sce), index=False)
# Out:
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-04-25
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x36562b84
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2143 rows and 3322590 columns
# Presolve time: 1.22s
# Presolved: 1603 rows, 185539 columns, 371048 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.29 seconds (1.56 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    17239 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 9
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    18285    9.9100000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 18285 iterations and 1.86 seconds (2.37 work units)
# Optimal objective  9.910000000e+02
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x0a7f32dc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2276 rows and 3325979 columns
# Presolve time: 1.30s
# Presolved: 1470 rows, 182150 columns, 364249 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.02s
#
# Barrier performed 0 iterations in 1.38 seconds (1.54 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    31371 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    33009    1.3240000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 33009 iterations and 2.02 seconds (1.85 work units)
# Optimal objective  1.324000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x5f626d08
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2789 rows and 3434864 columns
# Presolve time: 1.00s
# Presolved: 957 rows, 73265 columns, 146464 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.02 seconds (1.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       21    3.1400000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    58904 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    59044    3.1400000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 59044 iterations and 1.43 seconds (1.64 work units)
# Optimal objective  3.140000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xe44c6b13
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2321 rows and 3318399 columns
# Presolve time: 1.14s
# Presolved: 1425 rows, 189730 columns, 379390 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.22 seconds (1.54 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      454    9.0100000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    87262 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    88039    9.0100000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 88039 iterations and 1.75 seconds (1.85 work units)
# Optimal objective  9.010000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xd3915591
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2077 rows and 3109031 columns
# Presolve time: 1.24s
# Presolved: 1669 rows, 399098 columns, 798165 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.37 seconds (1.74 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   103877 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   105198    1.5170000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 105198 iterations and 1.93 seconds (2.17 work units)
# Optimal objective  1.517000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x10148be6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2145 rows and 3075480 columns
# Presolve time: 1.13s
# Presolved: 1601 rows, 432649 columns, 865270 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.854e+03
#  Factor NZ  : 2.823e+04 (roughly 2 MB of memory)
#  Factor Ops : 2.740e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 1.30 seconds (1.76 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   278393 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   279672    1.6180000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 279672 iterations and 2.22 seconds (2.38 work units)
# Optimal objective  1.618000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xe84e0308
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 2594 rows and 3436403 columns
# Presolve time: 1.27s
# Presolved: 1152 rows, 71726 columns, 143405 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.29 seconds (1.40 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       25    1.2900000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    46892 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    46980    1.2900000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 46980 iterations and 1.68 seconds (1.67 work units)
# Optimal objective  1.290000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x56efa7bf
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2087 rows and 3252100 columns
# Presolve time: 0.95s
# Presolved: 1659 rows, 256029 columns, 512021 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier performed 0 iterations in 1.05 seconds (1.62 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    24322 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    25523    1.2470000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 25523 iterations and 1.50 seconds (1.93 work units)
# Optimal objective  1.247000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x22f6aaa4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2087 rows and 3347032 columns
# Presolve time: 1.10s
# Presolved: 1659 rows, 161097 columns, 322173 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.17 seconds (1.55 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      530    8.2000000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     7793 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     8716    8.2000000e+02   0.000000e+00   8.000000e+00      1s
#     8721    8.2000000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 8721 iterations and 1.69 seconds (1.84 work units)
# Optimal objective  8.200000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x375f604c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2177 rows and 3312137 columns
# Presolve time: 1.02s
# Presolved: 1569 rows, 195992 columns, 391930 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.15s
#
# Barrier performed 0 iterations in 1.26 seconds (1.56 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    31696 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    33553    1.7570000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 33553 iterations and 1.73 seconds (1.88 work units)
# Optimal objective  1.757000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xa5bb5a5c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2151 rows and 3310749 columns
# Presolve time: 1.03s
# Presolved: 1595 rows, 197380 columns, 394727 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.02s
#
# Barrier performed 0 iterations in 1.13 seconds (1.57 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    19853 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    20939    1.0240000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 20939 iterations and 1.61 seconds (1.86 work units)
# Optimal objective  1.024000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xffb7016d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2270 rows and 3313371 columns
# Presolve time: 1.04s
# Presolved: 1476 rows, 194758 columns, 389460 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.02s
#
# Barrier performed 0 iterations in 1.12 seconds (1.55 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    34425 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    36431    1.4150000e+03   0.000000e+00   5.000000e+00      1s
#    36435    1.4150000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 36435 iterations and 1.63 seconds (1.88 work units)
# Optimal objective  1.415000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x5e077402
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2821 rows and 3441377 columns
# Presolve time: 1.34s
# Presolved: 925 rows, 66752 columns, 133444 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.36 seconds (1.35 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       14    3.0900000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    52277 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    52400    3.0900000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 52400 iterations and 1.84 seconds (1.62 work units)
# Optimal objective  3.090000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x7f0daea1
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2414 rows and 3341578 columns
# Presolve time: 1.17s
# Presolved: 1332 rows, 166551 columns, 333014 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.25 seconds (1.51 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       40    8.0900000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   138049 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   138399    8.0900000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 138399 iterations and 1.77 seconds (1.83 work units)
# Optimal objective  8.090000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x2c9732ef
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2079 rows and 3100104 columns
# Presolve time: 1.34s
# Presolved: 1667 rows, 408025 columns, 816019 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.324e+03
#  Factor NZ  : 4.546e+04 (roughly 3 MB of memory)
#  Factor Ops : 6.061e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.45 seconds (1.75 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   112090 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   113454    1.5700000e+03   0.000000e+00   4.000000e+00      2s
#   113456    1.5700000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 113456 iterations and 2.05 seconds (2.21 work units)
# Optimal objective  1.570000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x309ef00c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2157 rows and 3089127 columns
# Presolve time: 1.73s
# Presolved: 1589 rows, 419002 columns, 837968 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.89 seconds (1.74 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   259314 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   260490    1.4820000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 260490 iterations and 2.74 seconds (2.20 work units)
# Optimal objective  1.482000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xa58d2adf
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 2589 rows and 3438411 columns
# Presolve time: 1.79s
# Presolved: 1157 rows, 69718 columns, 139387 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.81 seconds (1.40 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       23    1.4300000e+02   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#    43712 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    43796    1.4300000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 43796 iterations and 2.30 seconds (1.67 work units)
# Optimal objective  1.430000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x24dfc142
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2073 rows and 3229915 columns
# Presolve time: 1.13s
# Presolved: 1673 rows, 278214 columns, 556394 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.04s
#
# Barrier performed 0 iterations in 1.29 seconds (1.65 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    43749 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    44996    1.3130000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 44996 iterations and 1.66 seconds (1.95 work units)
# Optimal objective  1.313000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xefffb305
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2085 rows and 3329933 columns
# Presolve time: 1.08s
# Presolved: 1661 rows, 178196 columns, 356369 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.15 seconds (1.56 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      507    8.7000000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    10689 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11619    8.7000000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 11619 iterations and 1.62 seconds (1.85 work units)
# Optimal objective  8.700000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x2ccd58f4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2177 rows and 3303686 columns
# Presolve time: 1.09s
# Presolved: 1569 rows, 204443 columns, 408821 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.03s
#
# Barrier performed 0 iterations in 1.20 seconds (1.57 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    38173 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    40143    1.8500000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 40143 iterations and 1.62 seconds (1.89 work units)
# Optimal objective  1.850000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xc2fead55
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2185 rows and 3319064 columns
# Presolve time: 1.03s
# Presolved: 1561 rows, 189065 columns, 378083 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.13 seconds (1.55 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    22384 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 7
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    23372    9.8900000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 23372 iterations and 1.75 seconds (2.37 work units)
# Optimal objective  9.890000000e+02
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x4a245e37
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2274 rows and 3312616 columns
# Presolve time: 1.61s
# Presolved: 1472 rows, 195513 columns, 390965 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.02s
#
# Barrier performed 0 iterations in 1.69 seconds (1.55 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#    33150 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.5000000e+01      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    34843    1.3440000e+03   0.000000e+00   3.500000e+01      2s
#    34856    1.3440000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 34856 iterations and 2.21 seconds (1.88 work units)
# Optimal objective  1.344000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x50faf42b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2777 rows and 3437049 columns
# Presolve time: 1.22s
# Presolved: 969 rows, 71080 columns, 142096 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.25 seconds (1.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       29    3.2300000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    50773 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    50914    3.2300000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 50914 iterations and 1.63 seconds (1.64 work units)
# Optimal objective  3.230000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x8c03abfc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2389 rows and 3331805 columns
# Presolve time: 1.14s
# Presolved: 1357 rows, 176324 columns, 352577 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.23 seconds (1.52 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    72221 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    72967    8.8000000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 72967 iterations and 1.67 seconds (1.82 work units)
# Optimal objective  8.800000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x6eda86d4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2069 rows and 3083787 columns
# Presolve time: 1.28s
# Presolved: 1677 rows, 424342 columns, 848654 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.530e+03
#  Factor NZ  : 3.988e+04 (roughly 3 MB of memory)
#  Factor Ops : 4.617e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 1.51 seconds (1.76 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   118024 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   119325    1.5360000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 119325 iterations and 2.18 seconds (2.21 work units)
# Optimal objective  1.536000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x4d4e77a0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2138 rows and 3070425 columns
# Presolve time: 1.47s
# Presolved: 1608 rows, 437704 columns, 875370 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.62 seconds (1.76 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   277256 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   278576    1.5800000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 278576 iterations and 2.66 seconds (2.34 work units)
# Optimal objective  1.580000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xf5f873e0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 2523 rows and 3432434 columns
# Presolve time: 1.82s
# Presolved: 1223 rows, 75695 columns, 151348 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.86 seconds (1.41 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       23    1.3600000e+02   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#    49297 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    49397    1.3600000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 49397 iterations and 2.43 seconds (1.68 work units)
# Optimal objective  1.360000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xa6aa34a6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2129 rows and 3247287 columns
# Presolve time: 1.24s
# Presolved: 1617 rows, 260842 columns, 521639 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.02s
#
# Barrier performed 0 iterations in 1.38 seconds (1.62 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    32875 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 18
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    33973    1.2230000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 33973 iterations and 1.98 seconds (2.45 work units)
# Optimal objective  1.223000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x6fd4a2fc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2104 rows and 3341441 columns
# Presolve time: 1.16s
# Presolved: 1642 rows, 166688 columns, 333341 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.430e+03
#  Factor NZ  : 4.294e+04 (roughly 3 MB of memory)
#  Factor Ops : 5.017e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.25 seconds (1.55 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      507    8.5000000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    10021 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    10914    8.5000000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 10914 iterations and 1.63 seconds (1.83 work units)
# Optimal objective  8.500000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xc51216b9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2195 rows and 3305778 columns
# Presolve time: 1.39s
# Presolved: 1551 rows, 202351 columns, 404637 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.02s
#
# Barrier performed 0 iterations in 1.49 seconds (1.57 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#    33121 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Extra simplex iterations after uncrush: 9
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    34851    1.7580000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 34851 iterations and 2.21 seconds (2.40 work units)
# Optimal objective  1.758000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x4cabd972
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2122 rows and 3312677 columns
# Presolve time: 1.16s
# Presolved: 1624 rows, 195452 columns, 390875 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.23 seconds (1.57 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    18230 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
# ...
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x8b555879
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2175 rows and 3283549 columns
# Presolve time: 0.71s
# Presolved: 1571 rows, 224580 columns, 449125 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.591e+03
#  Factor NZ  : 3.818e+04 (roughly 3 MB of memory)
#  Factor Ops : 4.050e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.77 seconds (1.58 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    29070 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    29927    9.7800000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 29927 iterations and 1.10 seconds (1.89 work units)
# Optimal objective  9.780000000e+02
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x4d762424
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2259 rows and 3292341 columns
# Presolve time: 0.71s
# Presolved: 1487 rows, 215788 columns, 431522 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier performed 0 iterations in 0.77 seconds (1.57 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    43340 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    44865    1.3850000e+03   0.000000e+00   8.000000e+00      1s
#    44871    1.3850000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 44871 iterations and 1.16 seconds (1.91 work units)
# Optimal objective  1.385000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x007e6a38
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2756 rows and 3420894 columns
# Presolve time: 0.75s
# Presolved: 990 rows, 87235 columns, 174395 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 0.77 seconds (1.38 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       18    3.8700000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    72764 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    72916    3.8700000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 72916 iterations and 1.07 seconds (1.66 work units)
# Optimal objective  3.870000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xa4271d1b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2350 rows and 3314201 columns
# Presolve time: 0.77s
# Presolved: 1396 rows, 193928 columns, 387777 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.261e+03
#  Factor NZ  : 3.626e+04 (roughly 2 MB of memory)
#  Factor Ops : 4.313e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.82 seconds (1.54 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    83880 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    84651    9.4400000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 84651 iterations and 1.18 seconds (1.85 work units)
# Optimal objective  9.440000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xdb991884
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2071 rows and 3096282 columns
# Presolve time: 0.85s
# Presolved: 1675 rows, 411847 columns, 823662 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.200e+03
#  Factor NZ  : 4.740e+04 (roughly 3 MB of memory)
#  Factor Ops : 6.172e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.95 seconds (1.75 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   113321 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   114779    1.5760000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 114779 iterations and 1.41 seconds (2.19 work units)
# Optimal objective  1.576000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x5c942a40
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2137 rows and 3073152 columns
# Presolve time: 0.93s
# Presolved: 1609 rows, 434977 columns, 869916 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.204e+03
#  Factor NZ  : 3.190e+04 (roughly 2 MB of memory)
#  Factor Ops : 3.283e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 1.02 seconds (1.76 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   279110 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   280434    1.6160000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 280434 iterations and 1.58 seconds (2.28 work units)
# Optimal objective  1.616000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xd1a60faf
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 2528 rows and 3417011 columns
# Presolve time: 0.90s
# Presolved: 1218 rows, 91118 columns, 182176 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 0.92 seconds (1.43 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       24    1.6100000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    66168 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    66282    1.6100000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 66282 iterations and 1.22 seconds (1.71 work units)
# Optimal objective  1.610000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xc7ab08d9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2109 rows and 3221169 columns
# Presolve time: 0.69s
# Presolved: 1637 rows, 286960 columns, 573890 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.332e+03
#  Factor NZ  : 4.800e+04 (roughly 3 MB of memory)
#  Factor Ops : 6.308e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.75 seconds (1.64 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    41736 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    42810    1.2580000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 42810 iterations and 1.09 seconds (1.97 work units)
# Optimal objective  1.258000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x80c59f24
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2082 rows and 3301915 columns
# Presolve time: 0.75s
# Presolved: 1664 rows, 206214 columns, 412407 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.309e+03
#  Factor NZ  : 3.784e+04 (roughly 3 MB of memory)
#  Factor Ops : 3.913e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.80 seconds (1.59 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      429    8.3600000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    11713 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    12557    8.3600000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 12557 iterations and 1.10 seconds (1.87 work units)
# Optimal objective  8.360000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xbc56100d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2162 rows and 3281685 columns
# Presolve time: 0.70s
# Presolved: 1584 rows, 226444 columns, 452823 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier performed 0 iterations in 0.76 seconds (1.59 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    44744 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.4000000e+01      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    46574    1.8330000e+03   0.000000e+00   1.400000e+01      1s
#    46577    1.8330000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 46577 iterations and 1.14 seconds (1.94 work units)
# Optimal objective  1.833000000e+03
