# %%
import numpy as np
import scipy.sparse as sp
import pandas as pd

import sys
sys.path.append('..')
import src

# %%
PARAMS = {
    'community': 'laurelhurst',
    'experiment_name': 'status_quo',
    # resource types should be the same as the column names in the resource_preference_pmf and resource_inventory_pmf
    'resource_types': ['water', 'food', 'meds', 'transp', 'comm',
                       'faid', 'warm', 'sani', 'power', 'shelter'], 
    'tau': 6, # isolation days
    'num_scenarios': 100,
    'n': 0.78773808, # degree distribution parameter
    'p': 0.02559534, # degree distribution parameter
    'social_tie': {
        'types': ['strong', 'weak'],
        'pmf':  [0.41296, 0.58704]
    },
    'distance_decay_alpha': -1.35, # distance decay parameter
    'distances_mat': np.load('../temp/laurelhurst_distance_matrix.npy'), # distance matrix
    'sharing_preference_pmf': pd.read_csv('../temp/laurelhurst_share_pref_PMF.csv'), # sharing preference matrix
    'sharing_priority': [3, 2, 1], # sharing priorities to [strong tie, weak tie, stranger]
    'resource_inventory_pmf': pd.read_csv('../temp/laurelhurst_resource_distr_PMF.csv') # resource inventory distribution
}

# %%
def p2p_single_resource_sharing(resource:str, 
                                tau:float, # isolation days
                                n:float, # negative binomial distribution parameter
                                p:float, # negative binomial distribution parameter
                                distance_decay_alpha:float, # distance decay parameter
                                distance_mat:np.matrix, # distance matrix
                                sharing_preference_PMF:pd.Series, 
                                resource_inventory_PMF:pd.Series,
                                social_tie_pmf:list,
                                social_tie_types:list = ['strong', 'weak'],
                                sharing_priority:list = [3, 2, 1],
                                seed:int=0):
    """Step 1: Community-based social network construction"""
    # create a community
    community = src.Community()
    num_nodes = distance_mat.shape[0]
    community.add_nodes_from(range(num_nodes))

    # generate social ties
    np.random.seed(seed)
    degree_list = np.random.negative_binomial(n, 
                                              p, 
                                              size=num_nodes)
    community.generate_social_ties(degrees=degree_list, 
                                   distance_matrix=distance_mat, 
                                   distance_decay_alpha=distance_decay_alpha, 
                                   seed=seed+1)
    community.split_social_ties(types=social_tie_types, 
                                pmf=social_tie_pmf, 
                                seed=seed+2)

    """Step 2: Community-based resource-sharing network construction"""
    # generate sharing preferences
    community.generate_sharing_preference(recipient=[0, 1, 2, 3], # [nobody, strong tie only, strong and weak ties only, everybody]
                                          pmf=sharing_preference_PMF, 
                                          name=resource+'_share_preference',
                                          seed=seed+3)

    """Step 3: Community-based resource inventory"""
    community.generate_resource_inventory(support=np.arange(0, len(resource_inventory_PMF)), 
                                          pmf=resource_inventory_PMF, 
                                          name=resource, 
                                          seed=seed+4)

    # create sharing network
    share_network = community.get_share_network(sharing_preference=resource+'_share_preference', 
                                                priority=sharing_priority)

    """Step 4: Community-based P2P resource-sharing model"""
    priority_matrix = community.get_share_priority_matrix(sharing_preference=resource+'_share_preference', 
                                                          priority=sharing_priority)
    resource_inventory = [community.nodes[n][resource] for n in community.nodes]
    model = src.ResourceSharingModel(wts_matrix=priority_matrix, 
                                     inventory=resource_inventory, 
                                     isolation_days=tau)
    model.solve()

    return community, share_network, model

# %%
# main script for running the status quo model
for sce in range(PARAMS['num_scenarios']):
    
    # directory name for saving the results
    dir = PARAMS['community'] + '/' + PARAMS['experiment_name'] + '/tau_' + str(PARAMS['tau']) # directory name
    # Create a dataframe to store the results
    inventory_df = pd.DataFrame(columns=PARAMS['resource_types'])
    resource_df = pd.DataFrame(columns=PARAMS['resource_types'])
    
    # run the model for each resource type
    for rsc in PARAMS['resource_types']:
        community, share_network, model = p2p_single_resource_sharing(resource=rsc,
                                                                    tau=PARAMS['tau'],
                                                                    n=PARAMS['n'],
                                                                    p=PARAMS['p'],
                                                                    social_tie_types = PARAMS['social_tie']['types'],
                                                                    social_tie_pmf = PARAMS['social_tie']['pmf'],
                                                                    distance_decay_alpha = PARAMS['distance_decay_alpha'],
                                                                    distance_mat = PARAMS['distances_mat'],
                                                                    sharing_preference_PMF = PARAMS['sharing_preference_pmf'][rsc],
                                                                    sharing_priority = PARAMS['sharing_priority'],
                                                                    resource_inventory_PMF = PARAMS['resource_inventory_pmf'][rsc],
                                                                    seed=sce)
        inventory_df[rsc] = model.inventory.flatten()
        resource_df[rsc] = model.resource.flatten()

        # save the sharing priority matrix in a sparse matrix
        sp.save_npz(dir + '/wij_mat_sce_{}_{}.npz'.format(sce, rsc), sp.csr_matrix(model.wts_matrix))
        # save the sharing plan in a sparse matrix
        sp.save_npz(dir + '/xij_mat_sce_{}_{}.npz'.format(sce, rsc), sp.csr_matrix(model.share_plan))

    # save the resource inventory vector in csv file
    inventory_df.to_csv(dir + '/q_vec_sce_{}.csv'.format(sce), index=False)
    # save the final resource vector in csv file
    resource_df.to_csv(dir + '/h_vec_sce_{}.csv'.format(sce), index=False)
# Out:
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-04-25
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x6c4181ab
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2108 rows and 3352919 columns
# Presolve time: 0.91s
# Presolved: 1638 rows, 155210 columns, 310401 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.188e+05
#  Factor NZ  : 1.852e+05 (roughly 50 MB of memory)
#  Factor Ops : 3.116e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.11 seconds (1.68 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      606    1.2560000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      239 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      856    1.2560000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 856 iterations and 1.52 seconds (2.02 work units)
# Optimal objective  1.256000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xe7041177
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2210 rows and 3334726 columns
# Presolve time: 1.07s
# Presolved: 1536 rows, 173403 columns, 346765 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.29 seconds (1.94 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      346 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1243    1.7960000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 1243 iterations and 1.71 seconds (2.27 work units)
# Optimal objective  1.796000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xd242b6d3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2741 rows and 3431615 columns
# Presolve time: 1.03s
# Presolved: 1005 rows, 76514 columns, 152939 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.206e+04
#  Factor NZ  : 7.606e+04 (roughly 18 MB of memory)
#  Factor Ops : 1.399e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.12 seconds (2.06 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      270 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4136    1.2510000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 4136 iterations and 1.46 seconds (2.35 work units)
# Optimal objective  1.251000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xa84f6fd4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2284 rows and 3295043 columns
# Presolve time: 1.12s
# Presolved: 1462 rows, 213086 columns, 426105 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.130e+05
#  Factor NZ  : 3.882e+05 (roughly 90 MB of memory)
#  Factor Ops : 1.997e+08 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.87519543e+05  2.43240831e+03  1.15e+03 2.00e+00  2.47e+00     1s
#    1   8.91282882e+04  4.10979987e+03  1.96e+02 4.19e-01  4.20e-01     1s
#
# Barrier performed 1 iterations in 1.41 seconds (2.10 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    14652    2.6500000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 14652 iterations and 1.82 seconds (2.52 work units)
# Optimal objective  2.650000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xbbec7e18
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2065 rows and 3123309 columns
# Presolve time: 1.28s
# Presolved: 1681 rows, 384820 columns, 769608 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 3.848e+05
#  Factor NZ  : 6.660e+05 (roughly 160 MB of memory)
#  Factor Ops : 3.318e+08 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.50 seconds (2.04 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2539    2.0610000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 2539 iterations and 1.92 seconds (2.53 work units)
# Optimal objective  2.061000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x49c57b54
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2112 rows and 3049896 columns
# Presolve time: 1.29s
# Presolved: 1634 rows, 458233 columns, 916444 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.582e+05
#  Factor NZ  : 8.811e+05 (roughly 200 MB of memory)
#  Factor Ops : 7.284e+08 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.63 seconds (2.15 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Extra simplex iterations after uncrush: 3
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7642    2.3800000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 7642 iterations and 2.18 seconds (3.19 work units)
# Optimal objective  2.380000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x84303630
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2482 rows and 3422395 columns
# Presolve time: 1.54s
# Presolved: 1264 rows, 85734 columns, 171383 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.714e+04
#  Factor NZ  : 6.284e+04 (roughly 16 MB of memory)
#  Factor Ops : 7.904e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.62 seconds (2.23 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      471    7.5900000e+02   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#     3187 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.2000000e+01      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3806    7.5900000e+02   0.000000e+00   4.200000e+01      2s
#     3809    7.5900000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 3809 iterations and 2.21 seconds (2.52 work units)
# Optimal objective  7.590000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x8cfcdd92
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2079 rows and 3267275 columns
# Presolve time: 1.18s
# Presolved: 1667 rows, 240854 columns, 481674 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.910e+05
#  Factor NZ  : 3.153e+05 (roughly 80 MB of memory)
#  Factor Ops : 8.549e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.62 seconds (1.85 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      826    1.7140000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#      903 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2065    1.7140000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 2065 iterations and 2.16 seconds (2.24 work units)
# Optimal objective  1.714000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x4fe2beee
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2065 rows and 3373295 columns
# Presolve time: 1.02s
# Presolved: 1681 rows, 134834 columns, 269653 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.001e+05
#  Factor NZ  : 1.496e+05 (roughly 40 MB of memory)
#  Factor Ops : 1.991e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.21 seconds (1.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      475    1.0230000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      187 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      668    1.0230000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 668 iterations and 1.74 seconds (1.69 work units)
# Optimal objective  1.023000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xb5682b53
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2135 rows and 3306581 columns
# Presolve time: 1.10s
# Presolved: 1611 rows, 201548 columns, 403034 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.015e+05
#  Factor NZ  : 3.926e+05 (roughly 80 MB of memory)
#  Factor Ops : 1.437e+08 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.23 seconds (1.84 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2691    2.5320000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 2691 iterations and 1.60 seconds (2.22 work units)
# Optimal objective  2.532000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x6d7466ff
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2111 rows and 3336773 columns
# Presolve time: 1.03s
# Presolved: 1635 rows, 171356 columns, 342687 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.302e+05
#  Factor NZ  : 2.041e+05 (roughly 50 MB of memory)
#  Factor Ops : 3.628e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.27 seconds (1.71 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      573    1.3030000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      503 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1213    1.3030000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 1213 iterations and 1.64 seconds (2.05 work units)
# Optimal objective  1.303000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x574d10af
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2215 rows and 3314851 columns
# Presolve time: 1.19s
# Presolved: 1531 rows, 193278 columns, 386515 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier performed 0 iterations in 1.53 seconds (1.95 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#      868 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1574    1.8480000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 1574 iterations and 1.92 seconds (2.25 work units)
# Optimal objective  1.848000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xdc89c85c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2772 rows and 3440236 columns
# Presolve time: 1.50s
# Presolved: 974 rows, 67893 columns, 135690 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.561e+04
#  Factor NZ  : 6.145e+04 (roughly 15 MB of memory)
#  Factor Ops : 9.258e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.59 seconds (2.03 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#      227 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2770    1.1880000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 2770 iterations and 1.98 seconds (2.32 work units)
# Optimal objective  1.188000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xdd6f04c8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2292 rows and 3303404 columns
# Presolve time: 1.23s
# Presolved: 1454 rows, 204725 columns, 409362 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.046e+05
#  Factor NZ  : 3.684e+05 (roughly 90 MB of memory)
#  Factor Ops : 1.801e+08 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.97468554e+05  2.40939987e+03  9.49e+02 2.01e+00  2.10e+00     1s
#
# Barrier performed 0 iterations in 1.48 seconds (1.83 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Extra simplex iterations after uncrush: 90
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    16698    2.7080000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 16698 iterations and 2.38 seconds (3.46 work units)
# Optimal objective  2.708000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x28e75561
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2058 rows and 3105271 columns
# Presolve time: 1.23s
# Presolved: 1688 rows, 402858 columns, 805691 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.028e+05
#  Factor NZ  : 7.032e+05 (roughly 170 MB of memory)
#  Factor Ops : 4.203e+08 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.45 seconds (1.58 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2473    2.0940000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 2473 iterations and 1.94 seconds (1.96 work units)
# Optimal objective  2.094000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x010731bd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2114 rows and 3049333 columns
# Presolve time: 1.37s
# Presolved: 1632 rows, 458796 columns, 917563 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.588e+05
#  Factor NZ  : 8.704e+05 (roughly 200 MB of memory)
#  Factor Ops : 7.167e+08 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.60856854e+06  2.43046695e+03  2.53e+03 2.01e+00  3.86e+00     2s
#
# Barrier performed 0 iterations in 1.77 seconds (1.83 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     8879    2.5140000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 8879 iterations and 2.41 seconds (2.33 work units)
# Optimal objective  2.514000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xde9fdc9e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2559 rows and 3441159 columns
# Presolve time: 1.38s
# Presolved: 1187 rows, 66970 columns, 133858 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.736e+04
#  Factor NZ  : 4.376e+04 (roughly 12 MB of memory)
#  Factor Ops : 4.169e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.43 seconds (2.23 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      303    7.1100000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     5268 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5696    7.1100000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 5696 iterations and 1.77 seconds (2.51 work units)
# Optimal objective  7.110000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xef071928
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2066 rows and 3247760 columns
# Presolve time: 1.06s
# Presolved: 1680 rows, 260369 columns, 520710 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier performed 0 iterations in 1.34 seconds (1.81 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1003 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1582    1.7750000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 1582 iterations and 1.74 seconds (2.14 work units)
# Optimal objective  1.775000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xc4072734
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2068 rows and 3362710 columns
# Presolve time: 0.93s
# Presolved: 1678 rows, 145419 columns, 290821 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.073e+05
#  Factor NZ  : 1.658e+05 (roughly 45 MB of memory)
#  Factor Ops : 2.413e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.14 seconds (1.67 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      460    1.0950000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      527 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1150    1.0950000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 1150 iterations and 1.52 seconds (1.99 work units)
# Optimal objective  1.095000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x7f1a49e5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2139 rows and 3293169 columns
# Presolve time: 0.92s
# Presolved: 1607 rows, 214960 columns, 429856 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.149e+05
#  Factor NZ  : 4.130e+05 (roughly 90 MB of memory)
#  Factor Ops : 1.611e+08 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.04 seconds (1.85 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2432    2.6260000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 2432 iterations and 1.38 seconds (2.22 work units)
# Optimal objective  2.626000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xe5b1cd1a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2122 rows and 3347298 columns
# Presolve time: 0.93s
# Presolved: 1624 rows, 160831 columns, 321628 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.195e+05
#  Factor NZ  : 1.883e+05 (roughly 50 MB of memory)
#  Factor Ops : 3.251e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.13 seconds (1.69 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      577    1.2650000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#       12 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      597    1.2650000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 597 iterations and 1.52 seconds (1.98 work units)
# Optimal objective  1.265000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x4c141fbf
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2235 rows and 3320843 columns
# Presolve time: 1.04s
# Presolved: 1511 rows, 187286 columns, 374521 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.449e+05
#  Factor NZ  : 2.587e+05 (roughly 60 MB of memory)
#  Factor Ops : 6.761e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.28 seconds (1.67 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1114 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2857    1.7540000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 2857 iterations and 1.80 seconds (2.02 work units)
# Optimal objective  1.754000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x430ca11f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2712 rows and 3430798 columns
# Presolve time: 1.04s
# Presolved: 1034 rows, 77331 columns, 154565 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.981e+04
#  Factor NZ  : 7.390e+04 (roughly 17 MB of memory)
#  Factor Ops : 1.266e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.12 seconds (1.63 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      344 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3805    1.2600000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3805 iterations and 1.48 seconds (1.92 work units)
# Optimal objective  1.260000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x69fe34c2
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2340 rows and 3306743 columns
# Presolve time: 1.04s
# Presolved: 1406 rows, 201386 columns, 402698 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.013e+05
#  Factor NZ  : 3.642e+05 (roughly 80 MB of memory)
#  Factor Ops : 1.764e+08 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.75739611e+05  2.35062936e+03  1.09e+03 2.01e+00  2.55e+00     1s
#    1   9.06041948e+04  3.90841092e+03  1.93e+02 5.14e-01  4.51e-01     1s
#
# Barrier performed 1 iterations in 1.26 seconds (1.84 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    12274    2.6000000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 12274 iterations and 1.58 seconds (2.25 work units)
# Optimal objective  2.600000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x036d3c02
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2064 rows and 3100815 columns
# Presolve time: 1.20s
# Presolved: 1682 rows, 407314 columns, 814595 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.254e+05
#  Factor NZ  : 6.023e+05 (roughly 140 MB of memory)
#  Factor Ops : 3.010e+08 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.71 seconds (2.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#     2193 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4465    2.0530000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 4465 iterations and 2.12 seconds (2.79 work units)
# Optimal objective  2.053000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x74ef7980
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2095 rows and 3046717 columns
# Presolve time: 1.29s
# Presolved: 1651 rows, 461412 columns, 922795 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.614e+05
#  Factor NZ  : 8.925e+05 (roughly 200 MB of memory)
#  Factor Ops : 7.461e+08 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.60 seconds (2.15 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7052    2.4050000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 7052 iterations and 1.94 seconds (2.66 work units)
# Optimal objective  2.405000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x7904799a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2483 rows and 3432117 columns
# Presolve time: 1.46s
# Presolved: 1263 rows, 76012 columns, 151950 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.026e+04
#  Factor NZ  : 4.672e+04 (roughly 13 MB of memory)
#  Factor Ops : 4.570e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.53 seconds (2.40 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      352    7.0400000e+02   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#     5064 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.1000000e+01      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5559    7.0400000e+02   0.000000e+00   3.100000e+01      2s
#     5561    7.0400000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 5561 iterations and 1.99 seconds (2.69 work units)
# Optimal objective  7.040000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x79edd3cd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2108 rows and 3264523 columns
# Presolve time: 0.97s
# Presolved: 1638 rows, 243606 columns, 487171 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.904e+05
#  Factor NZ  : 3.072e+05 (roughly 80 MB of memory)
#  Factor Ops : 8.250e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.34 seconds (2.13 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      805    1.6540000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1290 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2613    1.6540000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 2613 iterations and 1.75 seconds (2.51 work units)
# Optimal objective  1.654000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x41bc8e94
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2066 rows and 3375655 columns
# Presolve time: 0.93s
# Presolved: 1680 rows, 132474 columns, 264922 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 9.700e+04
#  Factor NZ  : 1.527e+05 (roughly 40 MB of memory)
#  Factor Ops : 2.132e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.11 seconds (1.64 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      485    1.0970000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      246 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      753    1.0970000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 753 iterations and 1.45 seconds (1.96 work units)
# Optimal objective  1.097000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x9764bc42
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2145 rows and 3299374 columns
# Presolve time: 0.95s
# Presolved: 1601 rows, 208755 columns, 417440 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.087e+05
#  Factor NZ  : 4.034e+05 (roughly 90 MB of memory)
#  Factor Ops : 1.511e+08 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.08 seconds (1.56 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2037    2.4880000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 2037 iterations and 1.43 seconds (1.95 work units)
# Optimal objective  2.488000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x007cb4ae
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2099 rows and 3341672 columns
# Presolve time: 0.94s
# Presolved: 1647 rows, 166457 columns, 332894 nonzeros
#
# ...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.372e+05
#  Factor NZ  : 2.083e+05 (roughly 60 MB of memory)
#  Factor Ops : 3.759e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.00 seconds (2.01 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      553    1.2320000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      734 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 13
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1554    1.2320000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 1554 iterations and 1.46 seconds (3.05 work units)
# Optimal objective  1.232000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x29256b69
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2225 rows and 3290938 columns
# Presolve time: 0.80s
# Presolved: 1521 rows, 217191 columns, 434346 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.682e+05
#  Factor NZ  : 2.917e+05 (roughly 70 MB of memory)
#  Factor Ops : 8.189e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.02 seconds (1.99 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1134 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3430    1.7700000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3430 iterations and 1.33 seconds (2.33 work units)
# Optimal objective  1.770000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x197602f5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2681 rows and 3415616 columns
# Presolve time: 0.85s
# Presolved: 1065 rows, 92513 columns, 184921 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.477e+04
#  Factor NZ  : 9.359e+04 (roughly 23 MB of memory)
#  Factor Ops : 1.838e+07 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.25416741e+05  1.36970803e+03  1.62e+02 1.62e+01  8.68e+00     1s
#    1   8.09495165e+04  3.52153734e+03  3.81e+01 2.49e-14  2.05e+00     1s
#    2   4.01443063e+03  3.13072384e+03  1.39e+00 2.13e-14  9.09e-02     1s
#
# Barrier performed 2 iterations in 0.95 seconds (2.12 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      329 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5623    1.5120000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 5623 iterations and 1.28 seconds (2.40 work units)
# Optimal objective  1.512000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x6b4514ab
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2290 rows and 3288736 columns
# Presolve time: 0.79s
# Presolved: 1456 rows, 219393 columns, 438707 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.193e+05
#  Factor NZ  : 3.943e+05 (roughly 100 MB of memory)
#  Factor Ops : 2.007e+08 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.15196051e+05  2.51933811e+03  1.13e+03 2.01e+00  2.54e+00     1s
#    1   9.77026141e+04  4.08742451e+03  2.03e+02 5.16e-01  4.58e-01     1s
#    2   1.57519196e+04  3.62821086e+03  2.78e+01 3.29e-02  6.55e-02     1s
#
# Barrier performed 2 iterations in 0.94 seconds (1.93 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    13816    2.7560000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 13816 iterations and 1.25 seconds (2.30 work units)
# Optimal objective  2.756000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x7ff89159
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2064 rows and 3101718 columns
# Presolve time: 0.75s
# Presolved: 1682 rows, 406411 columns, 812793 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.064e+05
#  Factor NZ  : 9.514e+05 (roughly 170 MB of memory)
#  Factor Ops : 8.567e+08 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.08349045e+06  3.26650480e+03  4.78e+03 2.02e+00  5.63e+00     1s
#
# Barrier performed 0 iterations in 0.93 seconds (1.79 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2812    2.0840000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 2812 iterations and 1.25 seconds (2.21 work units)
# Optimal objective  2.084000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xeaede54d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2097 rows and 3034597 columns
# Presolve time: 0.90s
# Presolved: 1649 rows, 473532 columns, 947038 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.735e+05
#  Factor NZ  : 9.163e+05 (roughly 200 MB of memory)
#  Factor Ops : 7.887e+08 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.74235127e+06  2.51330282e+03  2.73e+03 2.01e+00  4.04e+00     1s
#    1   3.25872188e+05  3.97077304e+03  4.86e+02 4.74e-01  7.17e-01     1s
#
# Barrier performed 1 iterations in 1.12 seconds (2.26 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     8171    2.4550000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 8171 iterations and 1.42 seconds (2.69 work units)
# Optimal objective  2.455000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xcaddce3b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2462 rows and 3412377 columns
# Presolve time: 0.88s
# Presolved: 1284 rows, 95752 columns, 191413 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.622e+04
#  Factor NZ  : 7.277e+04 (roughly 20 MB of memory)
#  Factor Ops : 9.821e+06 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.92687669e+05  9.28265640e+02  4.29e+02 2.32e+01  2.39e+01     1s
#
# Barrier performed 0 iterations in 0.96 seconds (2.30 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      562    8.6300000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     3752 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.6000000e+01      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4460    8.6300000e+02   0.000000e+00   3.600000e+01      1s
#     4465    8.6300000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 4465 iterations and 1.25 seconds (2.60 work units)
# Optimal objective  8.630000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x52886ba3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2073 rows and 3226406 columns
# Presolve time: 0.68s
# Presolved: 1673 rows, 281723 columns, 563421 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.193e+05
#  Factor NZ  : 3.734e+05 (roughly 100 MB of memory)
#  Factor Ops : 1.175e+08 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.95 seconds (1.84 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1549 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.2000000e+01      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3028    1.6950000e+03   0.000000e+00   1.200000e+01      1s
#     3029    1.6950000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3029 iterations and 1.25 seconds (2.22 work units)
# Optimal objective  1.695000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xe4f44865
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2071 rows and 3345729 columns
# Presolve time: 0.57s
# Presolved: 1675 rows, 162400 columns, 324788 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.172e+05
#  Factor NZ  : 1.692e+05 (roughly 50 MB of memory)
#  Factor Ops : 2.469e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.74 seconds (1.41 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      454    1.0280000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      661 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1342    1.0280000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 1342 iterations and 1.04 seconds (1.74 work units)
# Optimal objective  1.028000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x4fb9bcd2
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2127 rows and 3275923 columns
# Presolve time: 0.69s
# Presolved: 1619 rows, 232206 columns, 464351 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.321e+05
#  Factor NZ  : 4.394e+05 (roughly 100 MB of memory)
#  Factor Ops : 1.771e+08 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.77 seconds (1.87 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Extra simplex iterations after uncrush: 1
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2633    2.5690000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 2633 iterations and 1.11 seconds (2.60 work units)
# Optimal objective  2.569000000e+03
