# %%
import numpy as np
import scipy.sparse as sp
import pandas as pd

import sys
sys.path.append('..')
import src

# %%
PARAMS = {
    'community': 'southpark',
    'experiment_name': 'status_quo',
    # resource types should be the same as the column names in the resource_preference_pmf and resource_inventory_pmf
    'resource_types': ['water', 'food', 'meds', 'transp', 'comm',
                       'faid', 'warm', 'sani', 'power', 'shelter'], 
    'tau': 6, # isolation days
    'num_scenarios': 100,
    'n': 0.82661451, # degree distribution parameter
    'p': 0.06686762, # degree distribution parameter
    'social_tie': {
        'types': ['strong', 'weak'],
        'pmf':  [0.298, 0.702]
    },
    'distance_decay_alpha': -1.43, # distance decay parameter
    'distances_mat': np.load('../temp/southpark_distance_matrix.npy'), # distance matrix
    'sharing_preference_pmf': pd.read_csv('../temp/southpark_share_pref_PMF.csv'), # sharing preference matrix
    'sharing_priority': [3, 2, 1], # sharing priorities to [strong tie, weak tie, stranger]
    'resource_inventory_pmf': pd.read_csv('../temp/southpark_resource_distr_PMF.csv') # resource inventory distribution
}

# %%
def p2p_single_resource_sharing(resource:str, 
                                tau:float, # isolation days
                                n:float, # negative binomial distribution parameter
                                p:float, # negative binomial distribution parameter
                                distance_decay_alpha:float, # distance decay parameter
                                distance_mat:np.matrix, # distance matrix
                                sharing_preference_PMF:pd.Series, 
                                resource_inventory_PMF:pd.Series,
                                social_tie_pmf:list,
                                social_tie_types:list = ['strong', 'weak'],
                                sharing_priority:list = [3, 2, 1],
                                seed:int=0):
    """Step 1: Community-based social network construction"""
    # create a community
    community = src.Community()
    num_nodes = distance_mat.shape[0]
    community.add_nodes_from(range(num_nodes))

    # generate social ties
    np.random.seed(seed)
    degree_list = np.random.negative_binomial(n, 
                                              p, 
                                              size=num_nodes)
    community.generate_social_ties(degrees=degree_list, 
                                   distance_matrix=distance_mat, 
                                   distance_decay_alpha=distance_decay_alpha, 
                                   seed=seed+1)
    community.split_social_ties(types=social_tie_types, 
                                pmf=social_tie_pmf, 
                                seed=seed+2)

    """Step 2: Community-based resource-sharing network construction"""
    # generate sharing preferences
    community.generate_sharing_preference(recipient=[0, 1, 2, 3], # [nobody, strong tie only, strong and weak ties only, everybody]
                                          pmf=sharing_preference_PMF, 
                                          name=resource+'_share_preference',
                                          seed=seed+3)

    """Step 3: Community-based resource inventory"""
    community.generate_resource_inventory(support=np.arange(0, len(resource_inventory_PMF)), 
                                          pmf=resource_inventory_PMF, 
                                          name=resource, 
                                          seed=seed+4)

    # create sharing network
    share_network = community.get_share_network(sharing_preference=resource+'_share_preference', 
                                                priority=sharing_priority)

    """Step 4: Community-based P2P resource-sharing model"""
    priority_matrix = community.get_share_priority_matrix(sharing_preference=resource+'_share_preference', 
                                                          priority=sharing_priority)
    resource_inventory = [community.nodes[n][resource] for n in community.nodes]
    model = src.ResourceSharingModel(wts_matrix=priority_matrix, 
                                     inventory=resource_inventory, 
                                     isolation_days=tau)
    model.solve()

    return community, share_network, model

# %%
# main script for running the status quo model
for sce in range(PARAMS['num_scenarios']):
    
    # directory name for saving the results
    dir = PARAMS['community'] + '/' + PARAMS['experiment_name'] + '/tau_' + str(PARAMS['tau']) # directory name
    # Create a dataframe to store the results
    inventory_df = pd.DataFrame(columns=PARAMS['resource_types'])
    resource_df = pd.DataFrame(columns=PARAMS['resource_types'])
    
    # run the model for each resource type
    for rsc in PARAMS['resource_types']:
        community, share_network, model = p2p_single_resource_sharing(resource=rsc,
                                                                    tau=PARAMS['tau'],
                                                                    n=PARAMS['n'],
                                                                    p=PARAMS['p'],
                                                                    social_tie_types = PARAMS['social_tie']['types'],
                                                                    social_tie_pmf = PARAMS['social_tie']['pmf'],
                                                                    distance_decay_alpha = PARAMS['distance_decay_alpha'],
                                                                    distance_mat = PARAMS['distances_mat'],
                                                                    sharing_preference_PMF = PARAMS['sharing_preference_pmf'][rsc],
                                                                    sharing_priority = PARAMS['sharing_priority'],
                                                                    resource_inventory_PMF = PARAMS['resource_inventory_pmf'][rsc],
                                                                    seed=sce)
        inventory_df[rsc] = model.inventory.flatten()
        resource_df[rsc] = model.resource.flatten()

        # save the sharing priority matrix in a sparse matrix
        sp.save_npz(dir + '/wij_mat_sce_{}_{}.npz'.format(sce, rsc), sp.csr_matrix(model.wts_matrix))
        # save the sharing plan in a sparse matrix
        sp.save_npz(dir + '/xij_mat_sce_{}_{}.npz'.format(sce, rsc), sp.csr_matrix(model.share_plan))

    # save the resource inventory vector in csv file
    inventory_df.to_csv(dir + '/q_vec_sce_{}.csv'.format(sce), index=False)
    # save the final resource vector in csv file
    resource_df.to_csv(dir + '/h_vec_sce_{}.csv'.format(sce), index=False)
# Out:
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-04-25
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x30213a3f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1618 rows and 1802118 columns
# Presolve time: 0.45s
# Presolved: 1140 rows, 99523 columns, 199014 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.263e+04
#  Factor NZ  : 8.728e+04 (roughly 20 MB of memory)
#  Factor Ops : 1.137e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.53 seconds (0.90 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      307    7.2100000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1014 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 6
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1546    7.2100000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 1546 iterations and 0.81 seconds (1.30 work units)
# Optimal objective  7.210000000e+02
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xd84e9b75
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1811 rows and 1792583 columns
# Presolve time: 0.45s
# Presolved: 947 rows, 109058 columns, 218047 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 0.53 seconds (1.14 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      232    1.2660000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2169 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2815    1.2660000e+03   0.000000e+00   4.000000e+00      1s
# Extra simplex iterations after uncrush: 1
#     2818    1.2660000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 2818 iterations and 0.75 seconds (1.54 work units)
# Optimal objective  1.266000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xe7bb3472
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2145 rows and 1848336 columns
# Presolve time: 0.40s
# Presolved: 613 rows, 53305 columns, 106540 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.027e+04
#  Factor NZ  : 3.641e+04 (roughly 9 MB of memory)
#  Factor Ops : 5.589e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.44 seconds (0.86 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1577    9.7500000e+02   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#     9683 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.3600000e+02      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11539    9.7500000e+02   0.000000e+00   1.360000e+02      0s
# Extra simplex iterations after uncrush: 7
#    11599    9.7500000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 11599 iterations and 0.68 seconds (1.26 work units)
# Optimal objective  9.750000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x2a2d34d7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1896 rows and 1798337 columns
# Presolve time: 0.43s
# Presolved: 862 rows, 103304 columns, 206522 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.024e+04
#  Factor NZ  : 9.006e+04 (roughly 20 MB of memory)
#  Factor Ops : 2.208e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.50 seconds (0.99 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      939    1.4060000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     6893 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.7900000e+02      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     8354    1.4060000e+03   0.000000e+00   2.790000e+02      1s
# Extra simplex iterations after uncrush: 7
#     8383    1.4060000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 8383 iterations and 0.77 seconds (1.41 work units)
# Optimal objective  1.406000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x97cbab80
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1613 rows and 1696042 columns
# Presolve time: 0.52s
# Presolved: 1145 rows, 205599 columns, 411151 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.245e+05
#  Factor NZ  : 2.189e+05 (roughly 50 MB of memory)
#  Factor Ops : 6.453e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.69 seconds (1.20 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2925 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3575    1.4170000e+03   0.000000e+00   2.000000e+00      1s
#     3576    1.4170000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3576 iterations and 0.89 seconds (1.42 work units)
# Optimal objective  1.417000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x5fdc7adf
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1629 rows and 1681631 columns
# Presolve time: 0.59s
# Presolved: 1129 rows, 220010 columns, 439974 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.313e+05
#  Factor NZ  : 2.437e+05 (roughly 50 MB of memory)
#  Factor Ops : 8.239e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.80 seconds (1.22 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3062    1.4730000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     4420 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7949    1.4730000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 7949 iterations and 1.02 seconds (1.47 work units)
# Optimal objective  1.473000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x55ec34e7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1955 rows and 1856297 columns
# Presolve time: 0.52s
# Presolved: 803 rows, 45344 columns, 90641 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 7.792e+03
#  Factor NZ  : 1.233e+04 (roughly 3 MB of memory)
#  Factor Ops : 8.290e+05 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.55 seconds (0.91 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      161    5.6200000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    14308 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    14558    5.6200000e+02   0.000000e+00   4.000000e+00      1s
#    14561    5.6200000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 14561 iterations and 0.74 seconds (1.07 work units)
# Optimal objective  5.620000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x12f84fb2
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1728 rows and 1788105 columns
# Presolve time: 0.51s
# Presolved: 1030 rows, 113536 columns, 227000 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.640e+04
#  Factor NZ  : 1.191e+05 (roughly 30 MB of memory)
#  Factor Ops : 2.216e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.64 seconds (1.04 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      644    1.2870000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2761 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3766    1.2870000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3766 iterations and 0.85 seconds (1.23 work units)
# Optimal objective  1.287000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xd94f0d17
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1565 rows and 1846763 columns
# Presolve time: 0.42s
# Presolved: 1193 rows, 54878 columns, 109729 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.486e+04
#  Factor NZ  : 4.146e+04 (roughly 10 MB of memory)
#  Factor Ops : 2.789e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.61 seconds (0.82 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      826    5.7200000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#       28 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      858    5.7200000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 858 iterations and 0.82 seconds (0.99 work units)
# Optimal objective  5.720000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x5c7e96b8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1783 rows and 1820620 columns
# Presolve time: 0.55s
# Presolved: 975 rows, 81021 columns, 161950 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.676e+04
#  Factor NZ  : 8.742e+04 (roughly 20 MB of memory)
#  Factor Ops : 1.296e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.69 seconds (0.98 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      647    1.4190000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2987 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4024    1.4190000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 4024 iterations and 1.01 seconds (1.16 work units)
# Optimal objective  1.419000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xfc3b16ae
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1610 rows and 1801483 columns
# Presolve time: 0.90s
# Presolved: 1148 rows, 100158 columns, 200279 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.251e+04
#  Factor NZ  : 8.395e+04 (roughly 20 MB of memory)
#  Factor Ops : 1.016e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.13 seconds (0.89 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      314    7.0200000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1107 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1636    7.0200000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 1636 iterations and 1.41 seconds (1.07 work units)
# Optimal objective  7.020000000e+02
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x22e58b4c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1805 rows and 1783884 columns
# Presolve time: 0.58s
# Presolved: 953 rows, 117757 columns, 235430 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 7.265e+04
#  Factor NZ  : 1.315e+05 (roughly 30 MB of memory)
#  Factor Ops : 2.851e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.71 seconds (1.03 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2171 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.9300000e+02      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3600    1.3470000e+03   0.000000e+00   4.930000e+02      1s
#     3604    1.3470000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3604 iterations and 0.91 seconds (1.23 work units)
# Optimal objective  1.347000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x1912dad8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2156 rows and 1853364 columns
# Presolve time: 0.66s
# Presolved: 602 rows, 48277 columns, 96472 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.073e+04
#  Factor NZ  : 3.718e+04 (roughly 9 MB of memory)
#  Factor Ops : 5.659e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.72 seconds (1.07 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2130    1.0390000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     6786 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     9142    1.0390000e+03   0.000000e+00   7.000000e+00      1s
# Extra simplex iterations after uncrush: 51
#     9197    1.0390000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 9197 iterations and 1.05 seconds (1.53 work units)
# Optimal objective  1.039000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xa7c52e19
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1917 rows and 1806919 columns
# Presolve time: 0.57s
# Presolved: 841 rows, 94722 columns, 189341 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.02s
#
# Barrier statistics:
#  AA' NZ     : 5.329e+04
#  Factor NZ  : 1.015e+05 (roughly 22 MB of memory)
#  Factor Ops : 2.742e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.69 seconds (1.01 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2715    1.4800000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     4942 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.6030000e+03      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     8122    1.4800000e+03   0.000000e+00   3.603000e+03      1s
# Extra simplex iterations after uncrush: 4
#     8174    1.4800000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 8174 iterations and 0.96 seconds (1.44 work units)
# Optimal objective  1.480000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xae2aeac8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1624 rows and 1691129 columns
# Presolve time: 0.66s
# Presolved: 1134 rows, 210512 columns, 420973 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.340e+05
#  Factor NZ  : 2.319e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.063e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.87 seconds (1.20 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2206 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2791    1.4310000e+03   0.000000e+00   1.000000e+00      1s
#     2792    1.4310000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 2792 iterations and 1.08 seconds (1.40 work units)
# Optimal objective  1.431000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x42758531
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1641 rows and 1673519 columns
# Presolve time: 0.94s
# Presolved: 1117 rows, 228122 columns, 456192 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.460e+05
#  Factor NZ  : 2.950e+05 (roughly 60 MB of memory)
#  Factor Ops : 1.478e+08 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 1.27 seconds (1.05 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1553 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2303    1.5070000e+03   0.000000e+00   1.000000e+00      1s
#     2304    1.5070000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 2304 iterations and 1.69 seconds (1.28 work units)
# Optimal objective  1.507000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xa9af2216
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1942 rows and 1854478 columns
# Presolve time: 0.54s
# Presolved: 816 rows, 47163 columns, 94263 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 0.57 seconds (0.91 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      232    6.3200000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    11541 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11852    6.3200000e+02   0.000000e+00   1.000000e+00      1s
#    11853    6.3200000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 11853 iterations and 0.82 seconds (1.08 work units)
# Optimal objective  6.320000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x5c843dd8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1715 rows and 1772835 columns
# Presolve time: 0.65s
# Presolved: 1043 rows, 128806 columns, 257536 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 7.931e+04
#  Factor NZ  : 1.418e+05 (roughly 30 MB of memory)
#  Factor Ops : 2.961e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.81 seconds (1.07 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      657    1.3510000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2337 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3383    1.3510000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3383 iterations and 1.11 seconds (1.28 work units)
# Optimal objective  1.351000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xafb1928f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1581 rows and 1848576 columns
# Presolve time: 0.47s
# Presolved: 1177 rows, 53065 columns, 106101 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.004e+04
#  Factor NZ  : 3.354e+04 (roughly 9 MB of memory)
#  Factor Ops : 1.953e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.54 seconds (0.67 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      206    4.9700000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      822 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1176    4.9700000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 1176 iterations and 0.74 seconds (0.83 work units)
# Optimal objective  4.970000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x0ee68db4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1780 rows and 1810483 columns
# Presolve time: 0.55s
# Presolved: 978 rows, 91158 columns, 182209 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.578e+04
#  Factor NZ  : 1.056e+05 (roughly 24 MB of memory)
#  Factor Ops : 1.847e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.71 seconds (1.01 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Extra simplex iterations after uncrush: 1
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      691    1.5340000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2908 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4005    1.5340000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 4005 iterations and 0.95 seconds (1.20 work units)
# Optimal objective  1.534000000e+03
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x2680562b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1617 rows and 1809024 columns
# Presolve time: 0.53s
# Presolved: 1141 rows, 92617 columns, 185192 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.520e+04
#  Factor NZ  : 7.365e+04 (roughly 20 MB of memory)
#  Factor Ops : 8.469e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.64 seconds (0.87 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      307    7.1700000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     1190 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1708    7.1700000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 1708 iterations and 0.86 seconds (1.05 work units)
# Optimal objective  7.170000000e+02
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xec9fe2f0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1834 rows and 1792784 columns
# Presolve time: 0.60s
# Presolved: 924 rows, 108857 columns, 217643 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.400e+04
#  Factor NZ  : 1.155e+05 (roughly 27 MB of memory)
#  Factor Ops : 2.190e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.71 seconds (1.22 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2157 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.6600000e+03      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2915    1.1780000e+03   0.000000e+00   2.660000e+03      1s
# Extra simplex iterations after uncrush: 11
#     2931    1.1780000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 2931 iterations and 0.98 seconds (1.66 work units)
# Optimal objective  1.178000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xe9c5aa3d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2133 rows and 1846395 columns
# Presolve time: 0.49s
# Presolved: 625 rows, 55246 columns, 110425 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.314e+04
#  Factor NZ  : 4.239e+04 (roughly 10 MB of memory)
#  Factor Ops : 7.167e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.56 seconds (0.88 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      562    1.0170000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     8396 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.1500000e+02      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     9294    1.0170000e+03   0.000000e+00   7.150000e+02      1s
# Extra simplex iterations after uncrush: 3
#     9316    1.0170000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 9316 iterations and 0.83 seconds (1.29 work units)
# Optimal objective  1.017000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x2afdc6c0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1940 rows and 1806613 columns
# Presolve time: 0.58s
# Presolved: 818 rows, 95028 columns, 189963 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier performed 0 iterations in 0.67 seconds (1.23 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     7306 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.1200000e+02      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     8649    1.3920000e+03   0.000000e+00   2.120000e+02      1s
# Extra simplex iterations after uncrush: 3
#     8672    1.3920000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 8672 iterations and 0.92 seconds (1.64 work units)
# Optimal objective  1.392000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x2259a700
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1617 rows and 1690020 columns
# Presolve time: 0.51s
# Presolved: 1141 rows, 211621 columns, 423192 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.324e+05
#  Factor NZ  : 2.260e+05 (roughly 60 MB of memory)
#  Factor Ops : 6.632e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.73 seconds (1.03 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2580 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 9.4000000e+01      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3192    1.3310000e+03   0.000000e+00   9.400000e+01      1s
#     3197    1.3310000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3197 iterations and 0.95 seconds (1.25 work units)
# Optimal objective  1.331000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xc9553d34
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1641 rows and 1677974 columns
# Presolve time: 0.56s
# Presolved: 1117 rows, 223667 columns, 447288 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 0.74 seconds (1.23 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     6134 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6844    1.3580000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 6844 iterations and 0.96 seconds (1.45 work units)
# Optimal objective  1.358000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x8012a26c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1937 rows and 1852426 columns
# Presolve time: 0.54s
# Presolved: 821 rows, 49215 columns, 98376 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 9.125e+03
#  Factor NZ  : 1.459e+04 (roughly 4 MB of memory)
#  Factor Ops : 1.150e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.58 seconds (0.90 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      200    5.9600000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    13023 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 50
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    13362    5.9600000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 13362 iterations and 0.92 seconds (1.48 work units)
# Optimal objective  5.960000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xc329a2b9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# ...
#  Factor Ops : 1.377e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.68 seconds (0.92 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Extra simplex iterations after uncrush: 1
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      315    7.5900000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      810 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1345    7.5900000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 1345 iterations and 1.00 seconds (1.12 work units)
# Optimal objective  7.590000000e+02
# /Users/lzy95/Documents/GitHub/Peer-to-peer-community-sharing/results/../src/community.py:230: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(self).todense()
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xefa4a631
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1781 rows and 1777956 columns
# Presolve time: 0.89s
# Presolved: 977 rows, 123685 columns, 247303 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 1.01 seconds (1.04 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     3307 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3976    1.3090000e+03   0.000000e+00   2.000000e+00      1s
# Extra simplex iterations after uncrush: 3
#     3980    1.3090000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3980 iterations and 1.33 seconds (1.46 work units)
# Optimal objective  1.309000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x409d8380
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 2134 rows and 1843163 columns
# Presolve time: 0.58s
# Presolved: 624 rows, 58478 columns, 116878 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 0.64 seconds (0.89 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1828    1.0680000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     7752 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 6.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     9952    1.0680000e+03   0.000000e+00   6.000000e+00      1s
# Extra simplex iterations after uncrush: 3
#     9958    1.0680000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 9958 iterations and 0.94 seconds (1.29 work units)
# Optimal objective  1.068000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x6522ebcb
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1870 rows and 1797357 columns
# Presolve time: 0.62s
# Presolved: 888 rows, 104284 columns, 208480 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.02s
#
# Barrier performed 0 iterations in 0.73 seconds (1.14 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     4922 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.4110000e+03      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6044    1.4860000e+03   0.000000e+00   1.411000e+03      1s
# Extra simplex iterations after uncrush: 2
#     6058    1.4860000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 6058 iterations and 1.00 seconds (1.55 work units)
# Optimal objective  1.486000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x6236d91f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1615 rows and 1693196 columns
# Presolve time: 0.66s
# Presolved: 1143 rows, 208445 columns, 416839 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 0.86 seconds (1.05 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2180 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Extra simplex iterations after uncrush: 2
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2801    1.4310000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 2801 iterations and 1.14 seconds (1.47 work units)
# Optimal objective  1.431000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x5cd52a22
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1617 rows and 1673697 columns
# Presolve time: 0.71s
# Presolved: 1141 rows, 227944 columns, 455839 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.509e+05
#  Factor NZ  : 2.804e+05 (roughly 60 MB of memory)
#  Factor Ops : 1.056e+08 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.96 seconds (1.23 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2894 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4441    1.4960000e+03   0.000000e+00   3.000000e+00      1s
#     4443    1.4960000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 4443 iterations and 1.20 seconds (1.47 work units)
# Optimal objective  1.496000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0xcec0506f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1936 rows and 1842594 columns
# Presolve time: 0.74s
# Presolved: 822 rows, 59047 columns, 118027 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.519e+04
#  Factor NZ  : 2.450e+04 (roughly 6 MB of memory)
#  Factor Ops : 2.538e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.80 seconds (1.07 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      273    7.8300000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#    16458 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.9000000e+02      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    16860    7.8300000e+02   0.000000e+00   5.900000e+02      1s
#    16862    7.8300000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 16862 iterations and 1.20 seconds (1.24 work units)
# Optimal objective  7.830000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x2925bdd5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1705 rows and 1770154 columns
# Presolve time: 0.67s
# Presolved: 1053 rows, 131487 columns, 262902 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 8.318e+04
#  Factor NZ  : 1.484e+05 (roughly 35 MB of memory)
#  Factor Ops : 3.106e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.85 seconds (1.10 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      616    1.3320000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     2584 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3593    1.3320000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 3593 iterations and 1.14 seconds (1.30 work units)
# Optimal objective  1.332000000e+03
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x9c57e930
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1575 rows and 1848011 columns
# Presolve time: 0.55s
# Presolved: 1183 rows, 53630 columns, 107229 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.403e+04
#  Factor NZ  : 3.914e+04 (roughly 10 MB of memory)
#  Factor Ops : 2.462e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.62 seconds (0.83 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      241    5.7400000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      547 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      950    5.7400000e+02   0.000000e+00   0.000000e+00      1s
#
# Solved in 950 iterations and 0.84 seconds (0.99 work units)
# Optimal objective  5.740000000e+02
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2758 rows, 1901641 columns and 3803282 nonzeros
# Model fingerprint: 0x77840e67
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 1769 rows and 1808406 columns
# Presolve time: 0.60s
# Presolved: 989 rows, 93235 columns, 186367 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.678e+04
#  Factor NZ  : 1.058e+05 (roughly 24 MB of memory)
#  Factor Ops : 1.748e+07 (less than 1 second per iteration)
#  Threads    : 8
#
# Barrier performed 0 iterations in 0.69 seconds (1.00 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      646    1.4280000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#     3074 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4113    1.4280000e+03   0.000000e+00   0.000000e+00      1s
#
# Solved in 4113 iterations and 0.90 seconds (1.19 work units)
# Optimal objective  1.428000000e+03
