# %%
import numpy as np
import scipy.sparse as sp
import pandas as pd
import networkx as nx

import sys
sys.path.append('..')
import src

# %% [markdown]
# Here we consider an idea social network that the whole community is fully connected, i.e., each household is connected to every other household with strong tie.

# %%
PARAMS = {
    'community': 'laurelhurst',
    'experiment_name': 'ideal_social_net',
    # resource types should be the same as the column names in the resource_preference_pmf and resource_inventory_pmf
    'resource_types': ['water', 'food', 'meds', 'transp', 'comm',
                       'faid', 'warm', 'sani', 'power', 'shelter'], 
    'tau': 5, # isolation days
    'num_scenarios': 100,
    'n': 0.78773808, # degree distribution parameter
    'p': 0.02559534, # degree distribution parameter
    'social_tie': {
        'types': ['strong', 'weak'],
        'pmf':  [1, 0]
    },
    'distance_decay_alpha': -1.35, # distance decay parameter
    'distances_mat': np.load('../temp/laurelhurst_distance_matrix.npy'), # distance matrix
    'sharing_preference_pmf': pd.read_csv('../temp/laurelhurst_share_pref_PMF.csv'), # sharing preference matrix
    'sharing_priority': [3, 2, 1], # sharing priorities to [strong tie, weak tie, stranger]
    'resource_inventory_pmf': pd.read_csv('../temp/laurelhurst_resource_distr_PMF.csv') # resource inventory distribution
}

# %%
def p2p_single_resource_sharing(resource:str, 
                                tau:float, # isolation days
                                n:float, # negative binomial distribution parameter
                                p:float, # negative binomial distribution parameter
                                distance_decay_alpha:float, # distance decay parameter
                                distance_mat:np.matrix, # distance matrix
                                sharing_preference_PMF:pd.Series, 
                                resource_inventory_PMF:pd.Series,
                                social_tie_pmf:list,
                                social_tie_types:list = ['strong', 'weak'],
                                sharing_priority:list = [3, 2, 1],
                                seed:int=0):
    """Step 1: Community-based social network construction"""
    # create a community
    community = src.Community()
    num_nodes = distance_mat.shape[0]
    community.add_nodes_from(range(num_nodes))

    # generate a fully connected social network
    community.add_edges_from(nx.complete_graph(num_nodes).edges)
    community.split_social_ties(types=social_tie_types, 
                                pmf=social_tie_pmf, 
                                seed=seed+2)

    """Step 2: Community-based resource-sharing network construction"""
    # generate sharing preferences
    community.generate_sharing_preference(recipient=[0, 1, 2, 3], # [nobody, strong tie only, strong and weak ties only, everybody]
                                          pmf=sharing_preference_PMF, 
                                          name=resource+'_share_preference',
                                          seed=seed+3)

    """Step 3: Community-based resource inventory"""
    community.generate_resource_inventory(support=np.arange(0, len(resource_inventory_PMF)), 
                                          pmf=resource_inventory_PMF, 
                                          name=resource, 
                                          seed=seed+4)

    # create sharing network
    share_network = community.get_share_network(sharing_preference=resource+'_share_preference', 
                                                priority=sharing_priority)

    """Step 4: Community-based P2P resource-sharing model"""
    priority_matrix = community.get_share_priority_matrix(sharing_preference=resource+'_share_preference', 
                                                          priority=sharing_priority)
    resource_inventory = [community.nodes[n][resource] for n in community.nodes]
    model = src.ResourceSharingModel(wts_matrix=priority_matrix, 
                                     inventory=resource_inventory, 
                                     isolation_days=tau)
    model.solve()

    return community, share_network, model

# %%
# main script for running the status quo model
for sce in range(PARAMS['num_scenarios']):
    
    # directory name for saving the results
    dir = PARAMS['community'] + '/' + PARAMS['experiment_name'] + '/tau_' + str(PARAMS['tau']) # directory name
    # Create a dataframe to store the results
    inventory_df = pd.DataFrame(columns=PARAMS['resource_types'])
    resource_df = pd.DataFrame(columns=PARAMS['resource_types'])
    
    # run the model for each resource type
    for rsc in PARAMS['resource_types']:
        community, share_network, model = p2p_single_resource_sharing(resource=rsc,
                                                                    tau=PARAMS['tau'],
                                                                    n=PARAMS['n'],
                                                                    p=PARAMS['p'],
                                                                    social_tie_types = PARAMS['social_tie']['types'],
                                                                    social_tie_pmf = PARAMS['social_tie']['pmf'],
                                                                    distance_decay_alpha = PARAMS['distance_decay_alpha'],
                                                                    distance_mat = PARAMS['distances_mat'],
                                                                    sharing_preference_PMF = PARAMS['sharing_preference_pmf'][rsc],
                                                                    sharing_priority = PARAMS['sharing_priority'],
                                                                    resource_inventory_PMF = PARAMS['resource_inventory_pmf'][rsc],
                                                                    seed=sce)
        inventory_df[rsc] = model.inventory.flatten()
        resource_df[rsc] = model.resource.flatten()

        # save the sharing priority matrix in a sparse matrix
        sp.save_npz(dir + '/wij_mat_sce_{}_{}.npz'.format(sce, rsc), sp.csr_matrix(model.wts_matrix))
        # save the sharing plan in a sparse matrix
        sp.save_npz(dir + '/xij_mat_sce_{}_{}.npz'.format(sce, rsc), sp.csr_matrix(model.share_plan))

    # save the resource inventory vector in csv file
    inventory_df.to_csv(dir + '/q_vec_sce_{}.csv'.format(sce), index=False)
    # save the final resource vector in csv file
    resource_df.to_csv(dir + '/h_vec_sce_{}.csv'.format(sce), index=False)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-31
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x8c240fce
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2052 rows and 2837376 columns
# Presolve time: 1.91s
# Presolved: 1694 rows, 670753 columns, 1341506 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.3030000e+03   3.596626e-01   0.000000e+00      2s
#        1    3.3030000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   216117 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   216746    3.3030000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 216746 iterations and 2.80 seconds (2.05 work units)
# Optimal objective  3.303000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x70b309dd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2097 rows and 2834809 columns
# Presolve time: 2.17s
# Presolved: 1649 rows, 673320 columns, 1346640 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.7760000e+03   2.878521e-01   0.000000e+00      2s
#        3    4.7760000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   529705 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 3s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      3s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   530603    4.7760000e+03   0.000000e+00   0.000000e+00      4s
#
# Solved in 530603 iterations and 3.63 seconds (2.56 work units)
# Optimal objective  4.776000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x5b6626aa
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2160 rows and 3308305 columns
# Presolve time: 2.31s
# Presolved: 1586 rows, 199824 columns, 399648 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.4200000e+02   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      124 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   193324 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 3s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      3s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   193451    9.4200000e+02   0.000000e+00   0.000000e+00      3s
#
# Solved in 193451 iterations and 3.23 seconds (1.61 work units)
# Optimal objective  9.420000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xed7ef402
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2016 rows and 3000004 columns
# Presolve time: 1.64s
# Presolved: 1730 rows, 508125 columns, 1016250 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.7030000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      336 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   454836 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   455175    2.7030000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 455175 iterations and 2.60 seconds (1.94 work units)
# Optimal objective  2.703000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xda939d47
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1976 rows and 2724968 columns
# Presolve time: 1.57s
# Presolved: 1770 rows, 783161 columns, 1566322 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9590000e+03   1.632463e-01   0.000000e+00      2s
#        2    4.9590000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   534005 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      3s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   534879    4.9590000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 534879 iterations and 2.98 seconds (2.59 work units)
# Optimal objective  4.959000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xcc58dd32
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2037 rows and 2827911 columns
# Presolve time: 1.49s
# Presolved: 1709 rows, 680218 columns, 1360436 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.8540000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      612 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   586811 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 3s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      3s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   587426    4.8540000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 587426 iterations and 3.25 seconds (2.37 work units)
# Optimal objective  4.854000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x5b5fd8c4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 1948 rows and 3372328 columns
# Presolve time: 1.36s
# Presolved: 1798 rows, 135801 columns, 271602 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.8700000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       70 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   132079 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   132152    3.8700000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 132152 iterations and 2.01 seconds (1.56 work units)
# Optimal objective  3.870000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x719be019
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1980 rows and 2749176 columns
# Presolve time: 1.45s
# Presolved: 1766 rows, 758953 columns, 1517906 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.1280000e+03   3.822115e-01   0.000000e+00      2s
#        1    4.1280000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   240555 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   241288    4.1280000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 241288 iterations and 2.39 seconds (2.16 work units)
# Optimal objective  4.128000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x049581b9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2023 rows and 2886009 columns
# Presolve time: 1.29s
# Presolved: 1723 rows, 622120 columns, 1244240 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.7030000e+03   6.875086e-01   0.000000e+00      1s
#        6    2.7030000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   280575 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   281094    2.7030000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 281094 iterations and 2.12 seconds (2.04 work units)
# Optimal objective  2.703000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x0bc267aa
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1975 rows and 2754469 columns
# Presolve time: 1.53s
# Presolved: 1771 rows, 753660 columns, 1507320 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.2255760e+03   6.446522e-02   0.000000e+00      2s
#        4    6.1560000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   638764 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   639811    6.1560000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 639811 iterations and 2.80 seconds (2.41 work units)
# Optimal objective  6.156000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xf6c006dd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2062 rows and 2838766 columns
# Presolve time: 1.52s
# Presolved: 1684 rows, 669363 columns, 1338726 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.3840000e+03   6.057269e-02   0.000000e+00      2s
#        1    3.3840000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   267691 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   268333    3.3840000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 268333 iterations and 2.49 seconds (2.16 work units)
# Optimal objective  3.384000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x53314ee5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2105 rows and 2846899 columns
# Presolve time: 1.58s
# Presolved: 1641 rows, 661230 columns, 1322460 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.8870000e+03   2.405134e-01   0.000000e+00      2s
#        4    4.8870000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   525955 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 3s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      3s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   526878    4.8870000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 526878 iterations and 3.34 seconds (2.66 work units)
# Optimal objective  4.887000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x7c306079
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2184 rows and 3333768 columns
# Presolve time: 1.82s
# Presolved: 1562 rows, 174361 columns, 348722 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.2700000e+02   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      106 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   170353 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   170462    9.2700000e+02   0.000000e+00   0.000000e+00      3s
#
# Solved in 170462 iterations and 2.72 seconds (1.57 work units)
# Optimal objective  9.270000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x2a5fb292
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2041 rows and 3057523 columns
# Presolve time: 1.61s
# Presolved: 1705 rows, 450606 columns, 901212 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4270000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      281 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   410666 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   410950    2.4270000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 410950 iterations and 2.70 seconds (1.90 work units)
# Optimal objective  2.427000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xb70201ab
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1993 rows and 2740009 columns
# Presolve time: 1.51s
# Presolved: 1753 rows, 768120 columns, 1536240 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.0040000e+03   1.399944e-01   0.000000e+00      2s
#        2    5.0040000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   527177 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      3s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   528063    5.0040000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 528063 iterations and 2.96 seconds (2.60 work units)
# Optimal objective  5.004000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xd5ad7c6e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2044 rows and 2855217 columns
# Presolve time: 1.57s
# Presolved: 1702 rows, 652912 columns, 1305824 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.4460000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      563 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   560619 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   561185    4.4460000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 561185 iterations and 2.91 seconds (2.18 work units)
# Optimal objective  4.446000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x27184381
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 1930 rows and 3375889 columns
# Presolve time: 1.52s
# Presolved: 1816 rows, 132240 columns, 264480 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.2900000e+02   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       62 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   128806 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   128871    4.2900000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 128871 iterations and 2.16 seconds (1.56 work units)
# Optimal objective  4.290000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xee408cf9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1986 rows and 2749105 columns
# Presolve time: 1.47s
# Presolved: 1760 rows, 759024 columns, 1518048 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.2360000e+03   7.648402e-02   0.000000e+00      2s
#        1    4.2360000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   314470 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   315224    4.2360000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 315224 iterations and 2.58 seconds (2.35 work units)
# Optimal objective  4.236000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x2d1d6708
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2022 rows and 2870710 columns
# Presolve time: 1.35s
# Presolved: 1724 rows, 637419 columns, 1274838 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8140000e+03   5.630682e-01   0.000000e+00      1s
#        7    2.8140000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   277420 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   277960    2.8140000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 277960 iterations and 2.29 seconds (2.07 work units)
# Optimal objective  2.814000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xc7667ee8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1971 rows and 2762293 columns
# Presolve time: 1.57s
# Presolved: 1775 rows, 745836 columns, 1491672 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.3613080e+03   6.191340e-02   0.000000e+00      2s
#        5    6.3330000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   698785 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 3s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      3s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   698827    6.3330000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 698827 iterations and 3.04 seconds (2.54 work units)
# Optimal objective  6.333000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xa6bd23f3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2066 rows and 2843333 columns
# Presolve time: 1.40s
# Presolved: 1680 rows, 664796 columns, 1329592 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.3600000e+03   6.429856e-02   0.000000e+00      2s
#        1    3.3600000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   283725 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   284362    3.3600000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 284362 iterations and 2.45 seconds (2.24 work units)
# Optimal objective  3.360000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xb3d24f01
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2088 rows and 2826664 columns
# Presolve time: 1.62s
# Presolved: 1658 rows, 681465 columns, 1362930 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.7880000e+03   1.884637e-01   0.000000e+00      2s
#        3    4.7880000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   553687 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 3s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      3s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   554586    4.7880000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 554586 iterations and 3.11 seconds (2.52 work units)
# Optimal objective  4.788000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xc46c4933
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2171 rows and 3322913 columns
# Presolve time: 1.72s
# Presolved: 1575 rows, 185216 columns, 370432 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.6900000e+02   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      112 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   179056 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   179171    9.6900000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 179171 iterations and 2.47 seconds (1.59 work units)
# Optimal objective  9.690000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xb9d7c98e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2041 rows and 3036903 columns
# Presolve time: 1.53s
# Presolved: 1705 rows, 471226 columns, 942452 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6400000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      304 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   412540 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   412847    2.6400000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 412847 iterations and 2.50 seconds (1.89 work units)
# Optimal objective  2.640000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xbf86cdee
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1974 rows and 2723169 columns
# Presolve time: 1.54s
# Presolved: 1772 rows, 784960 columns, 1569920 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9890000e+03   1.705437e-01   0.000000e+00      2s
#        2    4.9890000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   552498 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   553376    4.9890000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 553376 iterations and 2.93 seconds (2.50 work units)
# Optimal objective  4.989000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x3c23a829
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2027 rows and 2814121 columns
# Presolve time: 1.53s
# Presolved: 1719 rows, 694008 columns, 1388016 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.7400000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      625 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   604561 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 3s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      3s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   605189    4.7400000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 605189 iterations and 3.33 seconds (2.32 work units)
# Optimal objective  4.740000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xb314578b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 1935 rows and 3369649 columns
# Presolve time: 1.46s
# Presolved: 1811 rows, 138480 columns, 276960 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.0800000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       72 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   133752 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   133827    4.0800000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 133827 iterations and 2.13 seconds (1.61 work units)
# Optimal objective  4.080000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xabfb5188
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2008 rows and 2770924 columns
# Presolve time: 1.48s
# Presolved: 1738 rows, 737205 columns, 1474410 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.1040000e+03   7.259241e-02   0.000000e+00      2s
#        1    4.1040000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   351571 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   352305    4.1040000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 352305 iterations and 2.91 seconds (2.25 work units)
# Optimal objective  4.104000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x29fe1f88
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2016 rows and 2871460 columns
# Presolve time: 1.30s
# Presolved: 1730 rows, 636669 columns, 1273338 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8290000e+03   7.325073e-01   0.000000e+00      1s
#        6    2.8290000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   272229 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   272761    2.8290000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 272761 iterations and 2.23 seconds (2.05 work units)
# Optimal objective  2.829000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x8e774ddb
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1979 rows and 2753639 columns
# Presolve time: 2.01s
# Presolved: 1767 rows, 754490 columns, 1508980 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.0750000e+03   4.850341e-01   0.000000e+00      2s
#        8    6.0750000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   711892 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 3s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      3s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   711945    6.0750000e+03   0.000000e+00   0.000000e+00      4s
#
# Solved in 711945 iterations and 3.66 seconds (2.43 work units)
# Optimal objective  6.075000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x77d485bc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2039 rows and 2834189 columns
# Presolve time: 1.52s
# Presolved: 1707 rows, 673940 columns, 1347880 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2490000e+03   5.337838e-02   0.000000e+00      2s
#        1    3.2490000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   229981 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   230599    3.2490000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 230599 iterations and 2.57 seconds (2.09 work units)
# Optimal objective  3.249000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xdc54f22e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2098 rows and 2832634 columns
# Presolve time: 1.53s
# Presolved: 1648 rows, 675495 columns, 1350990 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.6320000e+03   1.639222e-01   0.000000e+00      2s
#        3    4.6320000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   524670 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   525549    4.6320000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 525549 iterations and 2.95 seconds (2.45 work units)
# Optimal objective  4.632000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xadea31b0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2180 rows and 3308489 columns
# Presolve time: 1.38s
# Presolved: 1566 rows, 199640 columns, 399280 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0020000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      121 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   194161 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   194285    1.0020000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 194285 iterations and 2.11 seconds (1.60 work units)
# Optimal objective  1.002000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xd9360241
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2042 rows and 3017450 columns
# Presolve time: 1.46s
# Presolved: 1704 rows, 490679 columns, 981358 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6880000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      322 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   439621 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   439946    2.6880000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 439946 iterations and 2.55 seconds (1.91 work units)
# Optimal objective  2.688000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x612ed223
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
# ...
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   253880 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   254419    2.7960000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 254419 iterations and 2.25 seconds (2.05 work units)
# Optimal objective  2.796000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x3c39072f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1964 rows and 2740817 columns
# Presolve time: 1.52s
# Presolved: 1782 rows, 767312 columns, 1534624 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.0870000e+03   5.151455e-01   0.000000e+00      2s
#        8    6.0870000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   717447 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   717521    6.0870000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 717521 iterations and 2.91 seconds (2.52 work units)
# Optimal objective  6.087000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x5bb18ca2
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2075 rows and 2851889 columns
# Presolve time: 1.36s
# Presolved: 1671 rows, 656240 columns, 1312480 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.3090000e+03   1.773575e-01   0.000000e+00      1s
#        1    3.3090000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   254783 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   255413    3.3090000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 255413 iterations and 2.31 seconds (2.16 work units)
# Optimal objective  3.309000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x57623103
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2090 rows and 2831194 columns
# Presolve time: 1.53s
# Presolved: 1656 rows, 676935 columns, 1353870 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.8180000e+03   2.259156e-01   0.000000e+00      2s
#        3    4.8180000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   526131 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   527047    4.8180000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 527047 iterations and 2.77 seconds (2.45 work units)
# Optimal objective  4.818000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xcd0bfc8d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2165 rows and 3289645 columns
# Presolve time: 1.32s
# Presolved: 1581 rows, 218484 columns, 436968 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1610000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      134 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   213569 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   213706    1.1610000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 213706 iterations and 2.05 seconds (1.62 work units)
# Optimal objective  1.161000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xde1977bc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2020 rows and 3008385 columns
# Presolve time: 1.51s
# Presolved: 1726 rows, 499744 columns, 999488 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8320000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      319 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   449279 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   449601    2.8320000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 449601 iterations and 2.59 seconds (1.94 work units)
# Optimal objective  2.832000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x55c17874
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1986 rows and 2733925 columns
# Presolve time: 1.52s
# Presolved: 1760 rows, 774204 columns, 1548408 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.0340000e+03   5.449863e-01   0.000000e+00      2s
#        4    5.0340000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   526558 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   527441    5.0340000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 527441 iterations and 2.77 seconds (2.56 work units)
# Optimal objective  5.034000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x8b8d09ca
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2032 rows and 2832244 columns
# Presolve time: 1.52s
# Presolved: 1714 rows, 675885 columns, 1351770 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.8480000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#      594 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   586074 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 3s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      3s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   586671    4.8480000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 586671 iterations and 3.18 seconds (2.34 work units)
# Optimal objective  4.848000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x121c987f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 1935 rows and 3337029 columns
# Presolve time: 1.39s
# Presolved: 1811 rows, 171100 columns, 342200 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.8300000e+02   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       92 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#   165192 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   165287    4.8300000e+02   0.000000e+00   0.000000e+00      2s
#
# Solved in 165287 iterations and 2.04 seconds (1.62 work units)
# Optimal objective  4.830000000e+02
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x99dac867
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2014 rows and 2775334 columns
# Presolve time: 1.43s
# Presolved: 1732 rows, 732795 columns, 1465590 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.1130000e+03   1.358507e-01   0.000000e+00      2s
#        1    4.1130000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   324751 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   325485    4.1130000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 325485 iterations and 2.47 seconds (2.21 work units)
# Optimal objective  4.113000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0xbadcd082
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 2017 rows and 2873329 columns
# Presolve time: 1.32s
# Presolved: 1729 rows, 634800 columns, 1269600 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.7480000e+03   1.078757e+00   0.000000e+00      1s
#        9    2.7480000e+03   0.000000e+00   0.000000e+00      1s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   121136 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   121672    2.7480000e+03   0.000000e+00   0.000000e+00      2s
#
# Solved in 121672 iterations and 2.14 seconds (2.00 work units)
# Optimal objective  2.748000000e+03
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10700 CPU @ 2.90GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3746 rows, 3508129 columns and 7016258 nonzeros
# Model fingerprint: 0x9ebd4aa1
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+00]
# Presolve removed 1961 rows and 2745983 columns
# Presolve time: 1.54s
# Presolved: 1785 rows, 762146 columns, 1524292 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.3826560e+03   6.357972e-02   0.000000e+00      2s
#        5    6.2820000e+03   0.000000e+00   0.000000e+00      2s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#   723253 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   723304    6.2820000e+03   0.000000e+00   0.000000e+00      3s
#
# Solved in 723304 iterations and 2.91 seconds (2.54 work units)
# Optimal objective  6.282000000e+03
